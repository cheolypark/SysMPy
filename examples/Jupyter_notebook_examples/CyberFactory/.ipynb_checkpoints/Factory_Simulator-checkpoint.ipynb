# %%
import os
import sys 
sys.path.insert(0, os.path.abspath('..\..\..\..\sysmpy'))  
from sysmpy import *  
from Factory import p

# %%
await p.sim(until=10, use_web_distributor=True)
# Out:
# The simulation is connected to the web distributor.
# At Time 0, "Supplying" waiting.
# At Time 0, "Casting and Cutting" waiting.
# At Time 0, "Heating" waiting.
# At Time 0, "Hot Rolling" waiting.
# At Time 0, "Scalping" waiting.
# At Time 0, "Cold Rolling" waiting.
# At Time 0, "Annealing" waiting.
# At Time 0, "Pickling" waiting.
# At Time 0, "Finish Rolling" waiting.
# At Time 0, "Slitting" waiting.
# At Time 0, "Inspection" waiting.
# At Time 0, "Supplying" activated.
# At Time 0, "Supplying" sends.
# At Time 1, "Supplying" completed.
# At Time 1, "Supplying" waiting.
# At Time 0, "Casting and Cutting" activated.
# At Time 0, "Casting and Cutting" sends.
# At Time 1, "Casting and Cutting" completed.
# At Time 1, "Casting and Cutting" waiting.
# At Time 0, "Heating" activated.
# At Time 0, "Heating" sends.
# At Time 1, "Heating" completed.
# At Time 1, "Heating" waiting.
# At Time 0, "Hot Rolling" activated.
# At Time 0, "Hot Rolling" sends.
# At Time 1, "Hot Rolling" completed.
# At Time 1, "Hot Rolling" waiting.
# At Time 0, "Scalping" activated.
# At Time 0, "Scalping" sends.
# At Time 1, "Scalping" completed.
# At Time 1, "Scalping" waiting.
# At Time 0, "Cold Rolling" activated.
# At Time 0, "Cold Rolling" sends.
# At Time 1, "Cold Rolling" completed.
# At Time 1, "Cold Rolling" waiting.
# At Time 0, "Annealing" activated.
# At Time 0, "Annealing" sends.
# At Time 1, "Annealing" completed.
# At Time 1, "Annealing" waiting.
# At Time 0, "Pickling" activated.
# At Time 0, "Pickling" sends.
# At Time 1, "Pickling" completed.
# At Time 1, "Pickling" waiting.
# At Time 0, "Finish Rolling" activated.
# At Time 0, "Finish Rolling" sends.
# At Time 1, "Finish Rolling" completed.
# At Time 1, "Finish Rolling" waiting.
# At Time 0, "Slitting" activated.
# At Time 0, "Slitting" sends.
# At Time 1, "Slitting" completed.
# At Time 1, "Slitting" waiting.
# At Time 0, "Inspection" activated.
# At Time 1, "Inspection" completed.
# At Time 1, "Inspection" waiting.
# At Time 1, "Process_END" simulation 0.
# At Time 1, "Supplying" activated.
# At Time 1, "Supplying" sends.
# At Time 2, "Supplying" completed.
# At Time 2, "Supplying" waiting.
# At Time 1, "Casting and Cutting" activated.
# At Time 1, "Casting and Cutting" sends.
# At Time 2, "Casting and Cutting" completed.
# At Time 2, "Casting and Cutting" waiting.
# At Time 1, "Heating" activated.
# At Time 1, "Heating" sends.
# At Time 2, "Heating" completed.
# At Time 2, "Heating" waiting.
# At Time 1, "Hot Rolling" activated.
# At Time 1, "Hot Rolling" sends.
# At Time 2, "Hot Rolling" completed.
# At Time 2, "Hot Rolling" waiting.
# At Time 1, "Scalping" activated.
# At Time 1, "Scalping" sends.
# At Time 2, "Scalping" completed.
# At Time 2, "Scalping" waiting.
# At Time 1, "Cold Rolling" activated.
# At Time 1, "Cold Rolling" sends.
# At Time 2, "Cold Rolling" completed.
# At Time 2, "Cold Rolling" waiting.
# At Time 1, "Annealing" activated.
# At Time 1, "Annealing" sends.
# At Time 2, "Annealing" completed.
# At Time 2, "Annealing" waiting.
# At Time 1, "Pickling" activated.
# At Time 1, "Pickling" sends.
# At Time 2, "Pickling" completed.
# At Time 2, "Pickling" waiting.
# At Time 1, "Finish Rolling" activated.
# At Time 1, "Finish Rolling" sends.
# At Time 2, "Finish Rolling" completed.
# At Time 2, "Finish Rolling" waiting.
# At Time 1, "Slitting" activated.
# At Time 1, "Slitting" sends.
# At Time 2, "Slitting" completed.
# At Time 2, "Slitting" waiting.
# At Time 1, "Inspection" activated.
# At Time 2, "Inspection" completed.
# At Time 2, "Inspection" waiting.
# At Time 2, "Process_END" simulation 1.
# At Time 2, "Supplying" activated.
# At Time 2, "Supplying" sends.
# At Time 3, "Supplying" completed.
# At Time 3, "Supplying" waiting.
# At Time 2, "Casting and Cutting" activated.
# At Time 2, "Casting and Cutting" sends.
# At Time 3, "Casting and Cutting" completed.
# At Time 3, "Casting and Cutting" waiting.
# At Time 2, "Heating" activated.
# At Time 2, "Heating" sends.
# At Time 3, "Heating" completed.
# At Time 3, "Heating" waiting.
# At Time 2, "Hot Rolling" activated.
# At Time 2, "Hot Rolling" sends.
# At Time 3, "Hot Rolling" completed.
# At Time 3, "Hot Rolling" waiting.
# At Time 2, "Scalping" activated.
# At Time 2, "Scalping" sends.
# At Time 3, "Scalping" completed.
# At Time 3, "Scalping" waiting.
# At Time 2, "Cold Rolling" activated.
# At Time 2, "Cold Rolling" sends.
# At Time 3, "Cold Rolling" completed.
# At Time 3, "Cold Rolling" waiting.
# At Time 2, "Annealing" activated.
# At Time 2, "Annealing" sends.
# At Time 3, "Annealing" completed.
# At Time 3, "Annealing" waiting.
# At Time 2, "Pickling" activated.
# At Time 2, "Pickling" sends.
# At Time 3, "Pickling" completed.
# At Time 3, "Pickling" waiting.
# At Time 2, "Finish Rolling" activated.
# At Time 2, "Finish Rolling" sends.
# At Time 3, "Finish Rolling" completed.
# At Time 3, "Finish Rolling" waiting.
# At Time 2, "Slitting" activated.
# At Time 2, "Slitting" sends.
# At Time 3, "Slitting" completed.
# At Time 3, "Slitting" waiting.
# At Time 2, "Inspection" activated.
# At Time 3, "Inspection" completed.
# At Time 3, "Inspection" waiting.
# At Time 3, "Process_END" simulation 2.
# At Time 3, "Supplying" activated.
# At Time 3, "Supplying" sends.
# At Time 4, "Supplying" completed.
# At Time 4, "Supplying" waiting.
# At Time 3, "Casting and Cutting" activated.
# At Time 3, "Casting and Cutting" sends.
# At Time 4, "Casting and Cutting" completed.
# At Time 4, "Casting and Cutting" waiting.
# At Time 3, "Heating" activated.
# At Time 3, "Heating" sends.
# At Time 4, "Heating" completed.
# At Time 4, "Heating" waiting.
# At Time 3, "Hot Rolling" activated.
# At Time 3, "Hot Rolling" sends.
# At Time 4, "Hot Rolling" completed.
# At Time 4, "Hot Rolling" waiting.
# At Time 3, "Scalping" activated.
# At Time 3, "Scalping" sends.
# At Time 4, "Scalping" completed.
# At Time 4, "Scalping" waiting.
# At Time 3, "Cold Rolling" activated.
# At Time 3, "Cold Rolling" sends.
# At Time 4, "Cold Rolling" completed.
# At Time 4, "Cold Rolling" waiting.
# At Time 3, "Annealing" activated.
# At Time 3, "Annealing" sends.
# At Time 4, "Annealing" completed.
# At Time 4, "Annealing" waiting.
# At Time 3, "Pickling" activated.
# At Time 3, "Pickling" sends.
# At Time 4, "Pickling" completed.
# At Time 4, "Pickling" waiting.
# At Time 3, "Finish Rolling" activated.
# At Time 3, "Finish Rolling" sends.
# At Time 4, "Finish Rolling" completed.
# At Time 4, "Finish Rolling" waiting.
# At Time 3, "Slitting" activated.
# At Time 3, "Slitting" sends.
# At Time 4, "Slitting" completed.
# At Time 4, "Slitting" waiting.
# At Time 3, "Inspection" activated.
# At Time 4, "Inspection" completed.
# At Time 4, "Inspection" waiting.
# At Time 4, "Process_END" simulation 3.
# At Time 4, "Supplying" activated.
# At Time 4, "Supplying" sends.
# At Time 5, "Supplying" completed.
# At Time 5, "Supplying" waiting.
# At Time 4, "Casting and Cutting" activated.
# At Time 4, "Casting and Cutting" sends.
# At Time 5, "Casting and Cutting" completed.
# At Time 5, "Casting and Cutting" waiting.
# At Time 4, "Heating" activated.
# At Time 4, "Heating" sends.
# At Time 5, "Heating" completed.
# At Time 5, "Heating" waiting.
# At Time 4, "Hot Rolling" activated.
# At Time 4, "Hot Rolling" sends.
# At Time 5, "Hot Rolling" completed.
# At Time 5, "Hot Rolling" waiting.
# At Time 4, "Scalping" activated.
# At Time 4, "Scalping" sends.
# At Time 5, "Scalping" completed.
# At Time 5, "Scalping" waiting.
# At Time 4, "Cold Rolling" activated.
# At Time 4, "Cold Rolling" sends.
# At Time 5, "Cold Rolling" completed.
# At Time 5, "Cold Rolling" waiting.
# At Time 4, "Annealing" activated.
# At Time 4, "Annealing" sends.
# At Time 5, "Annealing" completed.
# At Time 5, "Annealing" waiting.
# At Time 4, "Pickling" activated.
# At Time 4, "Pickling" sends.
# At Time 5, "Pickling" completed.
# At Time 5, "Pickling" waiting.
# At Time 4, "Finish Rolling" activated.
# At Time 4, "Finish Rolling" sends.
# At Time 5, "Finish Rolling" completed.
# At Time 5, "Finish Rolling" waiting.
# At Time 4, "Slitting" activated.
# At Time 4, "Slitting" sends.
# At Time 5, "Slitting" completed.
# At Time 5, "Slitting" waiting.
# At Time 4, "Inspection" activated.
# At Time 5, "Inspection" completed.
# At Time 5, "Inspection" waiting.
# At Time 5, "Process_END" simulation 4.
# At Time 5, "Supplying" activated.
# At Time 5, "Supplying" sends.
# At Time 6, "Supplying" completed.
# At Time 6, "Supplying" waiting.
# At Time 5, "Casting and Cutting" activated.
# At Time 5, "Casting and Cutting" sends.
# At Time 6, "Casting and Cutting" completed.
# At Time 6, "Casting and Cutting" waiting.
# At Time 5, "Heating" activated.
# At Time 5, "Heating" sends.
# At Time 6, "Heating" completed.
# At Time 6, "Heating" waiting.
# At Time 5, "Hot Rolling" activated.
# At Time 5, "Hot Rolling" sends.
# At Time 6, "Hot Rolling" completed.
# At Time 6, "Hot Rolling" waiting.
# At Time 5, "Scalping" activated.
# At Time 5, "Scalping" sends.
# At Time 6, "Scalping" completed.
# At Time 6, "Scalping" waiting.
# At Time 5, "Cold Rolling" activated.
# At Time 5, "Cold Rolling" sends.
# At Time 6, "Cold Rolling" completed.
# At Time 6, "Cold Rolling" waiting.
# At Time 5, "Annealing" activated.
# At Time 5, "Annealing" sends.
# At Time 6, "Annealing" completed.
# At Time 6, "Annealing" waiting.
# At Time 5, "Pickling" activated.
# At Time 5, "Pickling" sends.
# At Time 6, "Pickling" completed.
# At Time 6, "Pickling" waiting.
# At Time 5, "Finish Rolling" activated.
# At Time 5, "Finish Rolling" sends.
# At Time 6, "Finish Rolling" completed.
# At Time 6, "Finish Rolling" waiting.
# At Time 5, "Slitting" activated.
# At Time 5, "Slitting" sends.
# At Time 6, "Slitting" completed.
# At Time 6, "Slitting" waiting.
# At Time 5, "Inspection" activated.
# At Time 6, "Inspection" completed.
# At Time 6, "Inspection" waiting.
# At Time 6, "Process_END" simulation 5.
# At Time 6, "Supplying" activated.
# At Time 6, "Supplying" sends.
# At Time 7, "Supplying" completed.
# At Time 7, "Supplying" waiting.
# At Time 6, "Casting and Cutting" activated.
# At Time 6, "Casting and Cutting" sends.
# At Time 7, "Casting and Cutting" completed.
# At Time 7, "Casting and Cutting" waiting.
# At Time 6, "Heating" activated.
# At Time 6, "Heating" sends.
# At Time 7, "Heating" completed.
# At Time 7, "Heating" waiting.
# At Time 6, "Hot Rolling" activated.
# At Time 6, "Hot Rolling" sends.
# At Time 7, "Hot Rolling" completed.
# At Time 7, "Hot Rolling" waiting.
# At Time 6, "Scalping" activated.
# At Time 6, "Scalping" sends.
# At Time 7, "Scalping" completed.
# At Time 7, "Scalping" waiting.
# At Time 6, "Cold Rolling" activated.
# At Time 6, "Cold Rolling" sends.
# At Time 7, "Cold Rolling" completed.
# At Time 7, "Cold Rolling" waiting.
# At Time 6, "Annealing" activated.
# At Time 6, "Annealing" sends.
# At Time 7, "Annealing" completed.
# At Time 7, "Annealing" waiting.
# At Time 6, "Pickling" activated.
# At Time 6, "Pickling" sends.
# At Time 7, "Pickling" completed.
# At Time 7, "Pickling" waiting.
# At Time 6, "Finish Rolling" activated.
# At Time 6, "Finish Rolling" sends.
# At Time 7, "Finish Rolling" completed.
# At Time 7, "Finish Rolling" waiting.
# At Time 6, "Slitting" activated.
# At Time 6, "Slitting" sends.
# At Time 7, "Slitting" completed.
# At Time 7, "Slitting" waiting.
# At Time 6, "Inspection" activated.
# At Time 7, "Inspection" completed.
# At Time 7, "Inspection" waiting.
# At Time 7, "Process_END" simulation 6.
# At Time 7, "Supplying" activated.
# At Time 7, "Supplying" sends.
# At Time 8, "Supplying" completed.
# At Time 8, "Supplying" waiting.
# At Time 7, "Casting and Cutting" activated.
# At Time 7, "Casting and Cutting" sends.
# At Time 8, "Casting and Cutting" completed.
# At Time 8, "Casting and Cutting" waiting.
# At Time 7, "Heating" activated.
# At Time 7, "Heating" sends.
# At Time 8, "Heating" completed.
# At Time 8, "Heating" waiting.
# At Time 7, "Hot Rolling" activated.
# At Time 7, "Hot Rolling" sends.
# At Time 8, "Hot Rolling" completed.
# At Time 8, "Hot Rolling" waiting.
# At Time 7, "Scalping" activated.
# At Time 7, "Scalping" sends.
# At Time 8, "Scalping" completed.
# At Time 8, "Scalping" waiting.
# At Time 7, "Cold Rolling" activated.
# At Time 7, "Cold Rolling" sends.
# At Time 8, "Cold Rolling" completed.
# At Time 8, "Cold Rolling" waiting.
# At Time 7, "Annealing" activated.
# At Time 7, "Annealing" sends.
# At Time 8, "Annealing" completed.
# At Time 8, "Annealing" waiting.
# At Time 7, "Pickling" activated.
# At Time 7, "Pickling" sends.
# At Time 8, "Pickling" completed.
# At Time 8, "Pickling" waiting.
# At Time 7, "Finish Rolling" activated.
# At Time 7, "Finish Rolling" sends.
# At Time 8, "Finish Rolling" completed.
# At Time 8, "Finish Rolling" waiting.
# At Time 7, "Slitting" activated.
# At Time 7, "Slitting" sends.
# At Time 8, "Slitting" completed.
# At Time 8, "Slitting" waiting.
# At Time 7, "Inspection" activated.
# At Time 8, "Inspection" completed.
# At Time 8, "Inspection" waiting.
# At Time 8, "Process_END" simulation 7.
# At Time 8, "Supplying" activated.
# At Time 8, "Supplying" sends.
# At Time 9, "Supplying" completed.
# At Time 9, "Supplying" waiting.
# At Time 8, "Casting and Cutting" activated.
# At Time 8, "Casting and Cutting" sends.
# At Time 9, "Casting and Cutting" completed.
# At Time 9, "Casting and Cutting" waiting.
# At Time 8, "Heating" activated.
# At Time 8, "Heating" sends.
# At Time 9, "Heating" completed.
# At Time 9, "Heating" waiting.
# At Time 8, "Hot Rolling" activated.
# At Time 8, "Hot Rolling" sends.
# At Time 9, "Hot Rolling" completed.
# At Time 9, "Hot Rolling" waiting.
# At Time 8, "Scalping" activated.
# At Time 8, "Scalping" sends.
# At Time 9, "Scalping" completed.
# At Time 9, "Scalping" waiting.
# At Time 8, "Cold Rolling" activated.
# At Time 8, "Cold Rolling" sends.
# At Time 9, "Cold Rolling" completed.
# At Time 9, "Cold Rolling" waiting.
# At Time 8, "Annealing" activated.
# At Time 8, "Annealing" sends.
# At Time 9, "Annealing" completed.
# At Time 9, "Annealing" waiting.
# At Time 8, "Pickling" activated.
# At Time 8, "Pickling" sends.
# At Time 9, "Pickling" completed.
# At Time 9, "Pickling" waiting.
# At Time 8, "Finish Rolling" activated.
# At Time 8, "Finish Rolling" sends.
# At Time 9, "Finish Rolling" completed.
# At Time 9, "Finish Rolling" waiting.
# At Time 8, "Slitting" activated.
# At Time 8, "Slitting" sends.
# At Time 9, "Slitting" completed.
# At Time 9, "Slitting" waiting.
# At Time 8, "Inspection" activated.
# At Time 9, "Inspection" completed.
# At Time 9, "Inspection" waiting.
# At Time 9, "Process_END" simulation 8.
# At Time 9, "Supplying" activated.
# At Time 9, "Supplying" sends.
# At Time 10, "Supplying" completed.
# At Time 10, "Supplying" waiting.
# At Time 9, "Casting and Cutting" activated.
# At Time 9, "Casting and Cutting" sends.
# At Time 10, "Casting and Cutting" completed.
# At Time 10, "Casting and Cutting" waiting.
# At Time 9, "Heating" activated.
# At Time 9, "Heating" sends.
# At Time 10, "Heating" completed.
# At Time 10, "Heating" waiting.
# At Time 9, "Hot Rolling" activated.
# At Time 9, "Hot Rolling" sends.
# At Time 10, "Hot Rolling" completed.
# At Time 10, "Hot Rolling" waiting.
# At Time 9, "Scalping" activated.
# At Time 9, "Scalping" sends.
# At Time 10, "Scalping" completed.
# At Time 10, "Scalping" waiting.
# At Time 9, "Cold Rolling" activated.
# At Time 9, "Cold Rolling" sends.
# At Time 10, "Cold Rolling" completed.
# At Time 10, "Cold Rolling" waiting.
# At Time 9, "Annealing" activated.
# At Time 9, "Annealing" sends.
# At Time 10, "Annealing" completed.
# At Time 10, "Annealing" waiting.
# At Time 9, "Pickling" activated.
# At Time 9, "Pickling" sends.
# At Time 10, "Pickling" completed.
# At Time 10, "Pickling" waiting.
# At Time 9, "Finish Rolling" activated.
# At Time 9, "Finish Rolling" sends.
# At Time 10, "Finish Rolling" completed.
# At Time 10, "Finish Rolling" waiting.
# At Time 9, "Slitting" activated.
# At Time 9, "Slitting" sends.
# At Time 10, "Slitting" completed.
# At Time 10, "Slitting" waiting.
# At Time 9, "Inspection" activated.
# At Time 10, "Inspection" completed.
# At Time 10, "Inspection" waiting.
# At Time 10, "Process_END" simulation 9.
# At Time 10, "Supplying" activated.
# At Time 10, "Supplying" sends.
# At Time 11, "Supplying" completed.
# At Time 11, "Supplying" waiting.
# At Time 10, "Casting and Cutting" activated.
# At Time 10, "Casting and Cutting" sends.
# At Time 11, "Casting and Cutting" completed.
# At Time 11, "Casting and Cutting" waiting.
# At Time 10, "Heating" activated.
# At Time 10, "Heating" sends.
# At Time 11, "Heating" completed.
# At Time 11, "Heating" waiting.
# At Time 10, "Hot Rolling" activated.
# At Time 10, "Hot Rolling" sends.
# At Time 11, "Hot Rolling" completed.
# At Time 11, "Hot Rolling" waiting.
# At Time 10, "Scalping" activated.
# At Time 10, "Scalping" sends.
# At Time 11, "Scalping" completed.
# At Time 11, "Scalping" waiting.
# At Time 10, "Cold Rolling" activated.
# At Time 10, "Cold Rolling" sends.
# At Time 11, "Cold Rolling" completed.
# At Time 11, "Cold Rolling" waiting.
# At Time 10, "Annealing" activated.
# At Time 10, "Annealing" sends.
# At Time 11, "Annealing" completed.
# At Time 11, "Annealing" waiting.
# At Time 10, "Pickling" activated.
# At Time 10, "Pickling" sends.
# At Time 11, "Pickling" completed.
# At Time 11, "Pickling" waiting.
# At Time 10, "Finish Rolling" activated.
# At Time 10, "Finish Rolling" sends.
# At Time 11, "Finish Rolling" completed.
# At Time 11, "Finish Rolling" waiting.
# At Time 10, "Slitting" activated.
# At Time 10, "Slitting" sends.
