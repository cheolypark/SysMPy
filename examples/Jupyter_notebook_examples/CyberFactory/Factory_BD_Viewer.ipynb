# %%
import os
import sys 
sys.path.insert(0, os.path.abspath('..\..\..\..\sysmpy'))  
from sysmpy import * 
from sysmpy.gui.mxgraph.tornado_gui_server import * 
from Factory import p

# %%
RunServer()
# Out:
# E:\SW-SysMPy\SysMPy\examples\Jupyter_notebook_examples\CyberFactory\images
# We use the existing tornado server!

# %%
show(p, diagram='ad', width=1400, height=300)
# Out:
#            <iframe
#                width="1400"
#                height="300"
#                src="http://127.0.0.1:9191/ad/?g=var A_Process = graph.insertVertex(parent, 'A Process', '', 905.0, 42.0, 30, 30, 'Process') /n var A_1_and = graph.insertVertex(parent, 'A.1 and', 'A', 905.0, 84.0, 30, 30, 'And') /n var A_Process_A_1_and = graph.insertEdge(parent, null, '', A_Process, A_1_and, 'Arrow_Edge_Process' ) /n var A_1_1_Production_Start = graph.insertVertex(parent, 'A.1.1 Production Start', '', 120.0, 141.0, 0, 0, 'Process') /n var A_1_and_A_1_1_Production_Start = graph.insertEdge(parent, null, '', A_1_and, A_1_1_Production_Start ) /n var A_1_2_Induction_Furnace = graph.insertVertex(parent, 'A.1.2 Induction Furnace', '', 280.0, 141.0, 0, 0, 'Process') /n var A_1_and_A_1_2_Induction_Furnace = graph.insertEdge(parent, null, '', A_1_and, A_1_2_Induction_Furnace ) /n var A_1_3_Heater = graph.insertVertex(parent, 'A.1.3 Heater', '', 440.0, 141.0, 0, 0, 'Process') /n var A_1_and_A_1_3_Heater = graph.insertEdge(parent, null, '', A_1_and, A_1_3_Heater ) /n var A_1_4_Hot_Rolling_Mill = graph.insertVertex(parent, 'A.1.4 Hot Rolling Mill', '', 600.0, 141.0, 0, 0, 'Process') /n var A_1_and_A_1_4_Hot_Rolling_Mill = graph.insertEdge(parent, null, '', A_1_and, A_1_4_Hot_Rolling_Mill ) /n var A_1_5_Scalper = graph.insertVertex(parent, 'A.1.5 Scalper', '', 760.0, 141.0, 0, 0, 'Process') /n var A_1_and_A_1_5_Scalper = graph.insertEdge(parent, null, '', A_1_and, A_1_5_Scalper ) /n var A_1_6_Cold_Rolling_Mill = graph.insertVertex(parent, 'A.1.6 Cold Rolling Mill', '', 920.0, 141.0, 0, 0, 'Process') /n var A_1_and_A_1_6_Cold_Rolling_Mill = graph.insertEdge(parent, null, '', A_1_and, A_1_6_Cold_Rolling_Mill ) /n var A_1_7_Annealing_Line = graph.insertVertex(parent, 'A.1.7 Annealing Line', '', 1080.0, 141.0, 0, 0, 'Process') /n var A_1_and_A_1_7_Annealing_Line = graph.insertEdge(parent, null, '', A_1_and, A_1_7_Annealing_Line ) /n var A_1_8_Pickling_Line = graph.insertVertex(parent, 'A.1.8 Pickling Line', '', 1240.0, 141.0, 0, 0, 'Process') /n var A_1_and_A_1_8_Pickling_Line = graph.insertEdge(parent, null, '', A_1_and, A_1_8_Pickling_Line ) /n var A_1_9_Finish_Rolling_Mill = graph.insertVertex(parent, 'A.1.9 Finish Rolling Mill', '', 1400.0, 141.0, 0, 0, 'Process') /n var A_1_and_A_1_9_Finish_Rolling_Mill = graph.insertEdge(parent, null, '', A_1_and, A_1_9_Finish_Rolling_Mill ) /n var A_1_10_Slitting_Line = graph.insertVertex(parent, 'A.1.10 Slitting Line', '', 1560.0, 141.0, 0, 0, 'Process') /n var A_1_and_A_1_10_Slitting_Line = graph.insertEdge(parent, null, '', A_1_and, A_1_10_Slitting_Line ) /n var A_1_11_Inspection_Line = graph.insertVertex(parent, 'A.1.11 Inspection Line', '', 1720.0, 141.0, 0, 0, 'Process') /n var A_1_and_A_1_11_Inspection_Line = graph.insertEdge(parent, null, '', A_1_and, A_1_11_Inspection_Line ) /n var A_1_1_1_Supplying = graph.insertVertex(parent, 'A.1.1.1 Supplying', 'Supplying', 80.0, 168.0, 80, 30, 'Action') /n var A_1_1_Production_Start_A_1_1_1_Supplying = graph.insertEdge(parent, null, '', A_1_1_Production_Start, A_1_1_1_Supplying ) /n var A_1_2_3_Casting_and_Cutting = graph.insertVertex(parent, 'A.1.2.3 Casting and Cutting', 'Casting and Cutting', 240.0, 168.0, 80, 30, 'Action') /n var A_1_2_Induction_Furnace_A_1_2_3_Casting_and_Cutting = graph.insertEdge(parent, null, '', A_1_2_Induction_Furnace, A_1_2_3_Casting_and_Cutting ) /n var A_1_3_3_Heating = graph.insertVertex(parent, 'A.1.3.3 Heating', 'Heating', 400.0, 168.0, 80, 30, 'Action') /n var A_1_3_Heater_A_1_3_3_Heating = graph.insertEdge(parent, null, '', A_1_3_Heater, A_1_3_3_Heating ) /n var A_1_4_3_Hot_Rolling = graph.insertVertex(parent, 'A.1.4.3 Hot Rolling', 'Hot Rolling', 560.0, 168.0, 80, 30, 'Action') /n var A_1_4_Hot_Rolling_Mill_A_1_4_3_Hot_Rolling = graph.insertEdge(parent, null, '', A_1_4_Hot_Rolling_Mill, A_1_4_3_Hot_Rolling ) /n var A_1_5_2_Scalping = graph.insertVertex(parent, 'A.1.5.2 Scalping', 'Scalping', 720.0, 168.0, 80, 30, 'Action') /n var A_1_5_Scalper_A_1_5_2_Scalping = graph.insertEdge(parent, null, '', A_1_5_Sc ...

# %%
show(p, diagram='bd', width=1450, height=750, Hide_No_Action_Process=True)
# Out:
#            <iframe
#                width="1450"
#                height="750"
#                src="http://127.0.0.1:9191/bd/?g=var ID2142550129416 = graph.insertVertex(parent, 'Process.and.Production Start', 'Production Start', 20.0, 20.0, 150, 100, 'Process/8/') /n graph.insertVertex(ID2142550129416, null, '', 0, 0, 150, 70, 'ProcessImage/8/image=http://127.0.0.1:9191/images/Production Start.png/8/') /n graph.insertVertex(ID2142550129416, null, 'Supplying', 0, 0, 150, 20, 'ActionBoundary/8/') /n var ID2142549688200 = graph.insertVertex(parent, 'Copper Cathode', 'Copper Cathode', 200.0, 20.0, 150, 100, 'Item/8/') /n graph.insertVertex(ID2142549688200, null, '', 0, 0, 150, 70, 'ItemImage/8/image=http://127.0.0.1:9191/images/Copper Cathode.png/8/') /n var ID2142567214088_p = graph.insertVertex(ID2142549688200, null, '', 0, 0, 150, 20, 'Property') /n var ID2142567214088_k = graph.insertVertex(ID2142567214088_p, null, 'Thick.', 0, 0, 75.0, 20, 'Property') /n var ID2142567214088_v = graph.insertVertex(ID2142567214088_p, 'Copper Cathode.Thickness', 'null', 75.0, 0, 75.0, 20, 'PropertyValue') /n var ID2142567213320_p = graph.insertVertex(ID2142549688200, null, '', 0, 0, 150, 20, 'Property') /n var ID2142567213320_k = graph.insertVertex(ID2142567213320_p, null, 'Width.', 0, 0, 75.0, 20, 'Property') /n var ID2142567213320_v = graph.insertVertex(ID2142567213320_p, 'Copper Cathode.Width', 'null', 75.0, 0, 75.0, 20, 'PropertyValue') /n var ID2142550391560_p = graph.insertVertex(ID2142549688200, null, '', 0, 0, 150, 20, 'Property') /n var ID2142550391560_k = graph.insertVertex(ID2142550391560_p, null, 'Lengt.', 0, 0, 75.0, 20, 'Property') /n var ID2142550391560_v = graph.insertVertex(ID2142550391560_p, 'Copper Cathode.Length', 'null', 75.0, 0, 75.0, 20, 'PropertyValue') /n var ID2142550391176_p = graph.insertVertex(ID2142549688200, null, '', 0, 0, 150, 20, 'Property') /n var ID2142550391176_k = graph.insertVertex(ID2142550391176_p, null, 'Tempe.', 0, 0, 75.0, 20, 'Property') /n var ID2142550391176_v = graph.insertVertex(ID2142550391176_p, 'Copper Cathode.Temperature', 'null', 75.0, 0, 75.0, 20, 'PropertyValue') /n var ID2142486403016 = graph.insertVertex(parent, 'Process.and.Induction Furnace', 'Induction Furnace', 380.0, 20.0, 150, 100, 'Process/8/') /n graph.insertVertex(ID2142486403016, null, '', 0, 0, 150, 70, 'ProcessImage/8/image=http://127.0.0.1:9191/images/Induction Furnace.png/8/') /n graph.insertVertex(ID2142486403016, null, 'Casting and Cutting', 0, 0, 150, 20, 'ActionBoundary/8/') /n var ID2142549684424_p = graph.insertVertex(ID2142486403016, null, '', 0, 0, 150, 20, 'Property') /n var ID2142549684424_k = graph.insertVertex(ID2142549684424_p, null, 'Speed.', 0, 0, 75.0, 20, 'Property') /n var ID2142549684424_v = graph.insertVertex(ID2142549684424_p, 'Process.and.Induction Furnace.Speed', 'null', 75.0, 0, 75.0, 20, 'PropertyValue') /n var ID2142549684808_p = graph.insertVertex(ID2142486403016, null, '', 0, 0, 150, 20, 'Property') /n var ID2142549684808_k = graph.insertVertex(ID2142549684808_p, null, 'Tempe.', 0, 0, 75.0, 20, 'Property') /n var ID2142549684808_v = graph.insertVertex(ID2142549684808_p, 'Process.and.Induction Furnace.Temperature', 'null', 75.0, 0, 75.0, 20, 'PropertyValue') /n var ID2142549685448 = graph.insertVertex(parent, 'Slab', 'Slab', 560.0, 20.0, 150, 100, 'Item/8/') /n graph.insertVertex(ID2142549685448, null, '', 0, 0, 150, 70, 'ItemImage/8/image=http://127.0.0.1:9191/images/Slab.png/8/') /n var ID2142549685768_p = graph.insertVertex(ID2142549685448, null, '', 0, 0, 150, 20, 'Property') /n var ID2142549685768_k = graph.insertVertex(ID2142549685768_p, null, 'Thick.', 0, 0, 75.0, 20, 'Property') /n var ID2142549685768_v = graph.insertVertex(ID2142549685768_p, 'Slab.Thickness', 'null', 75.0, 0, 75.0, 20, 'PropertyValue') /n var ID2142549686152_p = graph.insertVertex(ID2142549685448, null, '', 0, 0, 150, 20, 'Property') /n var ID2142549686152_k = graph.insertVertex(ID2142549686152_p, null, 'Width.', 0, 0, 75.0, 20, 'Property') /n var ID2142549686152_v = graph.insertVertex(ID2142549686152 ...
