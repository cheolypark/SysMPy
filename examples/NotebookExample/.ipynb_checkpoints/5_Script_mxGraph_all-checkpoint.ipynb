# %%
import os
import sys 
sys.path.insert(0, os.path.abspath('..\..\Core')) 
from gui_main import *

# %%
# Test 1
p = Process("process")

p_con1 = p.Condition("Condition 1")
p1 = p_con1.Process("P1")
p2 = p_con1.Process("P2")
p_act1 = p1.Action("Action1")  

p_con2 = p1.Condition("Condition 2")
p3 = p_con2.Process("P3")
p4 = p_con2.Process("P4") 
p_act1 = p3.Action("Action2")  
p_act2 = p4.Action("Action3")

p.Action("Action4") 
p.Action("Action5") 

IFrame("http://localhost:8080/?g=" + p.get_mxgraph(), width=1000, height=700)
# Out:
#         <iframe
#             width="1000"
#             height="700"
#             src="http://localhost:8080/?g=var A_process = graph.insertVertex(parent, 'A process', '', 305.0, 42.0, 30, 30, 'Process') /n A_process.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_And1 = graph.insertVertex(parent, 'A.1 And1', 'And1', 280.0, 84.0, 80, 30, 'Condition') /n A_1_And1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_process_A_1_And1 = graph.insertEdge(parent, null, '', A_process, A_1_And1, 'Arrow_Edge_Process' ) /n var A_1_1_P1 = graph.insertVertex(parent, 'A.1.1 P1', '', 200.0, 141.0, 0, 0, 'Process') /n A_1_1_P1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_And1_A_1_1_P1 = graph.insertEdge(parent, null, '', A_1_And1, A_1_1_P1 ) /n var A_1_2_P2 = graph.insertVertex(parent, 'A.1.2 P2', '', 440.0, 141.0, 0, 0, 'Process') /n A_1_2_P2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_And1_A_1_2_P2 = graph.insertEdge(parent, null, '', A_1_And1, A_1_2_P2 ) /n var A_2_Action4 = graph.insertVertex(parent, 'A.2 Action4', 'Action4', 280.0, 504.0, 80, 30, 'Action') /n A_2_Action4.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_3_Action5 = graph.insertVertex(parent, 'A.3 Action5', 'Action5', 280.0, 546.0, 80, 30, 'Action') /n A_3_Action5.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_2_Action4_A_3_Action5 = graph.insertEdge(parent, null, '', A_2_Action4, A_3_Action5 ) /n var A_process_END = graph.insertVertex(parent, 'A process_END', '', 305.0, 588.0, 30, 30, 'Process_END') /n A_process_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_3_Action5_A_process_END = graph.insertEdge(parent, null, '', A_3_Action5, A_process_END, 'Arrow_Edge_Process' ) /n var A_1_1_1_Action1 = graph.insertVertex(parent, 'A.1.1.1 Action1', 'Action1', 160.0, 168.0, 80, 30, 'Action') /n A_1_1_1_Action1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_1_P1_A_1_1_1_Action1 = graph.insertEdge(parent, null, '', A_1_1_P1, A_1_1_1_Action1 ) /n var A_1_2_P2_END = graph.insertVertex(parent, 'A.1.2 P2_END', '', 440.0, 435.0, 0, 0, 'Process_END') /n A_1_2_P2_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_2_P2_A_1_2_P2_END = graph.insertEdge(parent, null, '', A_1_2_P2, A_1_2_P2_END ) /n var A_1_1_2_And2 = graph.insertVertex(parent, 'A.1.1.2 And2', 'And2', 160.0, 210.0, 80, 30, 'Condition') /n A_1_1_2_And2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_1_1_Action1_A_1_1_2_And2 = graph.insertEdge(parent, null, '', A_1_1_1_Action1, A_1_1_2_And2 ) /n var A_1_1_2_1_P3 = graph.insertVertex(parent, 'A.1.1.2.1 P3', '', 120.0, 267.0, 0, 0, 'Process') /n A_1_1_2_1_P3.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_1_2_And2_A_1_1_2_1_P3 = graph.insertEdge(parent, null, '', A_1_1_2_And2, A_1_1_2_1_P3 ) /n var A_1_1_2_2_P4 = graph.insertVertex(parent, 'A.1.1.2.2 P4', '', 280.0, 267.0, 0, 0, 'Process') /n A_1_1_2_2_P4.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_1_2_And2_A_1_1_2_2_P4 = graph.insertEdge(parent, null, '', A_1_1_2_And2, A_1_1_2_2_P4 ) /n var A_1_1_2_1_1_Action2 = graph.insertVertex(parent, 'A.1.1.2.1.1 Action2', 'Action2', 80.0, 294.0, 80, 30, 'Action') /n A_1_1_2_1_1_Action2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_1_2_1_P3_A_1_1_2_1_1_Action2 = graph.insertEdge(parent, null, '', A_1_1_2_1_P3, A_1_1_2_1_1_Action2 ) /n var A_1_1_2_2_1_Action3 = graph.insertVertex(parent, 'A.1.1.2.2.1 Action3', 'Action3', 240.0, 294.0, 80, 30, 'Action') /n A_1_1_2_2_1_Action3.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_1_2_2_P4_A_1_1_2_2_1_Action3 = graph.insertEdge(parent, null, '', A_1_1_2_2_P4, A_1_1_2_2_1_Action3 ) /n var A_1_1_2_1_P3_END = graph.insertVertex(parent, 'A.1.1.2.1 P3_END', '', 120.0, 351.0, 0, 0, 'Process_END') /n A_1_1_2_1_P3_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_1_2_1_1_Action2_A_1_1_2_1_P3_END = graph.insertEdge(parent, null, ...
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Test 2
p = Process("process")

p_con1 = p.Condition("Condition 1")
p1 = p_con1.Process("P1")
p2 = p_con1.Process("P2")
p_act1 = p1.Action("Action1")  

p_con2 = p2.Condition("Condition 2")
p3 = p_con2.Process("P3")
p4 = p_con2.Process("P4") 
p_act1 = p3.Action("Action2")  
p_act2 = p4.Action("Action3")

p.Action("Action4") 
 
IFrame("http://localhost:8080/?g=" + p.get_mxgraph(), width=1000, height=700)
# Out:
#         <iframe
#             width="1000"
#             height="700"
#             src="http://localhost:8080/?g=var A_process = graph.insertVertex(parent, 'A process', '', 225.0, 42.0, 30, 30, 'Process') /n A_process.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_And1 = graph.insertVertex(parent, 'A.1 And1', 'And1', 200.0, 84.0, 80, 30, 'Condition') /n A_1_And1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_process_A_1_And1 = graph.insertEdge(parent, null, '', A_process, A_1_And1, 'Arrow_Edge_Process' ) /n var A_1_1_P1 = graph.insertVertex(parent, 'A.1.1 P1', '', 120.0, 141.0, 0, 0, 'Process') /n A_1_1_P1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_And1_A_1_1_P1 = graph.insertEdge(parent, null, '', A_1_And1, A_1_1_P1 ) /n var A_1_2_P2 = graph.insertVertex(parent, 'A.1.2 P2', '', 360.0, 141.0, 0, 0, 'Process') /n A_1_2_P2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_And1_A_1_2_P2 = graph.insertEdge(parent, null, '', A_1_And1, A_1_2_P2 ) /n var A_2_Action4 = graph.insertVertex(parent, 'A.2 Action4', 'Action4', 200.0, 462.0, 80, 30, 'Action') /n A_2_Action4.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_process_END = graph.insertVertex(parent, 'A process_END', '', 225.0, 504.0, 30, 30, 'Process_END') /n A_process_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_2_Action4_A_process_END = graph.insertEdge(parent, null, '', A_2_Action4, A_process_END, 'Arrow_Edge_Process' ) /n var A_1_1_1_Action1 = graph.insertVertex(parent, 'A.1.1.1 Action1', 'Action1', 80.0, 168.0, 80, 30, 'Action') /n A_1_1_1_Action1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_1_P1_A_1_1_1_Action1 = graph.insertEdge(parent, null, '', A_1_1_P1, A_1_1_1_Action1 ) /n var A_1_2_1_And2 = graph.insertVertex(parent, 'A.1.2.1 And2', 'And2', 320.0, 168.0, 80, 30, 'Condition') /n A_1_2_1_And2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_2_P2_A_1_2_1_And2 = graph.insertEdge(parent, null, '', A_1_2_P2, A_1_2_1_And2 ) /n var A_1_1_P1_END = graph.insertVertex(parent, 'A.1.1 P1_END', '', 120.0, 393.0, 0, 0, 'Process_END') /n A_1_1_P1_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_1_1_Action1_A_1_1_P1_END = graph.insertEdge(parent, null, '', A_1_1_1_Action1, A_1_1_P1_END ) /n var A_1_And1_END = graph.insertVertex(parent, 'A.1 And1_END', 'OR', 225.0, 420.0, 30, 30, 'Condition_END') /n A_1_And1_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_1_P1_END_A_1_And1_END = graph.insertEdge(parent, null, '', A_1_1_P1_END, A_1_And1_END ) /n var A_1_2_1_1_P3 = graph.insertVertex(parent, 'A.1.2.1.1 P3', '', 280.0, 225.0, 0, 0, 'Process') /n A_1_2_1_1_P3.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_2_1_And2_A_1_2_1_1_P3 = graph.insertEdge(parent, null, '', A_1_2_1_And2, A_1_2_1_1_P3 ) /n var A_1_2_1_2_P4 = graph.insertVertex(parent, 'A.1.2.1.2 P4', '', 440.0, 225.0, 0, 0, 'Process') /n A_1_2_1_2_P4.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_2_1_And2_A_1_2_1_2_P4 = graph.insertEdge(parent, null, '', A_1_2_1_And2, A_1_2_1_2_P4 ) /n var A_1_2_1_1_1_Action2 = graph.insertVertex(parent, 'A.1.2.1.1.1 Action2', 'Action2', 240.0, 252.0, 80, 30, 'Action') /n A_1_2_1_1_1_Action2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_2_1_1_P3_A_1_2_1_1_1_Action2 = graph.insertEdge(parent, null, '', A_1_2_1_1_P3, A_1_2_1_1_1_Action2 ) /n var A_1_2_1_2_1_Action3 = graph.insertVertex(parent, 'A.1.2.1.2.1 Action3', 'Action3', 400.0, 252.0, 80, 30, 'Action') /n A_1_2_1_2_1_Action3.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_2_1_2_P4_A_1_2_1_2_1_Action3 = graph.insertEdge(parent, null, '', A_1_2_1_2_P4, A_1_2_1_2_1_Action3 ) /n var A_1_2_1_1_P3_END = graph.insertVertex(parent, 'A.1.2.1.1 P3_END', '', 280.0, 309.0, 0, 0, 'Process_END') /n A_1_2_1_1_P3_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_2_1_1_1_Action2_A_1_2_1_1_P3_END = graph.insertEdge(pare ...
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Test 3
p = Process("process")

p_con1 = p.Condition("Condition 1")
p1 = p_con1.Process("P1")
p2 = p_con1.Process("P2")
p12 = p_con1.Process("P21")
p_act1 = p1.Action("Action1")  

p_con2 = p.Condition("Condition 2")
p3 = p_con2.Process("P3")
p4 = p_con2.Process("P4") 
p_act1 = p3.Action("Action2")  
p_act2 = p4.Action("Action3")

p.Action("Action4") 
 

IFrame("http://localhost:8080/?g=" + p.get_mxgraph(), width=1000, height=700)
# Out:
#         <iframe
#             width="1000"
#             height="700"
#             src="http://localhost:8080/?g=var A_process = graph.insertVertex(parent, 'A process', '', 265.0, 42.0, 30, 30, 'Process') /n A_process.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_And1 = graph.insertVertex(parent, 'A.1 And1', 'And1', 240.0, 84.0, 80, 30, 'Condition') /n A_1_And1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_process_A_1_And1 = graph.insertEdge(parent, null, '', A_process, A_1_And1, 'Arrow_Edge_Process' ) /n var A_1_1_P1 = graph.insertVertex(parent, 'A.1.1 P1', '', 120.0, 141.0, 0, 0, 'Process') /n A_1_1_P1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_And1_A_1_1_P1 = graph.insertEdge(parent, null, '', A_1_And1, A_1_1_P1 ) /n var A_1_2_P2 = graph.insertVertex(parent, 'A.1.2 P2', '', 280.0, 141.0, 0, 0, 'Process') /n A_1_2_P2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_And1_A_1_2_P2 = graph.insertEdge(parent, null, '', A_1_And1, A_1_2_P2 ) /n var A_1_3_P21 = graph.insertVertex(parent, 'A.1.3 P21', '', 440.0, 141.0, 0, 0, 'Process') /n A_1_3_P21.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_And1_A_1_3_P21 = graph.insertEdge(parent, null, '', A_1_And1, A_1_3_P21 ) /n var A_2_And2 = graph.insertVertex(parent, 'A.2 And2', 'And2', 240.0, 294.0, 80, 30, 'Condition') /n A_2_And2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_2_1_P3 = graph.insertVertex(parent, 'A.2.1 P3', '', 200.0, 351.0, 0, 0, 'Process') /n A_2_1_P3.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_2_And2_A_2_1_P3 = graph.insertEdge(parent, null, '', A_2_And2, A_2_1_P3 ) /n var A_2_2_P4 = graph.insertVertex(parent, 'A.2.2 P4', '', 360.0, 351.0, 0, 0, 'Process') /n A_2_2_P4.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_2_And2_A_2_2_P4 = graph.insertEdge(parent, null, '', A_2_And2, A_2_2_P4 ) /n var A_3_Action4 = graph.insertVertex(parent, 'A.3 Action4', 'Action4', 240.0, 504.0, 80, 30, 'Action') /n A_3_Action4.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_process_END = graph.insertVertex(parent, 'A process_END', '', 265.0, 546.0, 30, 30, 'Process_END') /n A_process_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_3_Action4_A_process_END = graph.insertEdge(parent, null, '', A_3_Action4, A_process_END, 'Arrow_Edge_Process' ) /n var A_1_1_1_Action1 = graph.insertVertex(parent, 'A.1.1.1 Action1', 'Action1', 80.0, 168.0, 80, 30, 'Action') /n A_1_1_1_Action1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_1_P1_A_1_1_1_Action1 = graph.insertEdge(parent, null, '', A_1_1_P1, A_1_1_1_Action1 ) /n var A_1_2_P2_END = graph.insertVertex(parent, 'A.1.2 P2_END', '', 280.0, 225.0, 0, 0, 'Process_END') /n A_1_2_P2_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_2_P2_A_1_2_P2_END = graph.insertEdge(parent, null, '', A_1_2_P2, A_1_2_P2_END ) /n var A_1_3_P21_END = graph.insertVertex(parent, 'A.1.3 P21_END', '', 440.0, 225.0, 0, 0, 'Process_END') /n A_1_3_P21_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_3_P21_A_1_3_P21_END = graph.insertEdge(parent, null, '', A_1_3_P21, A_1_3_P21_END ) /n var A_1_1_P1_END = graph.insertVertex(parent, 'A.1.1 P1_END', '', 120.0, 225.0, 0, 0, 'Process_END') /n A_1_1_P1_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_1_1_Action1_A_1_1_P1_END = graph.insertEdge(parent, null, '', A_1_1_1_Action1, A_1_1_P1_END ) /n var A_1_And1_END = graph.insertVertex(parent, 'A.1 And1_END', 'OR', 265.0, 252.0, 30, 30, 'Condition_END') /n A_1_And1_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_1_P1_END_A_1_And1_END = graph.insertEdge(parent, null, '', A_1_1_P1_END, A_1_And1_END ) /n var A_1_2_P2_END_A_1_And1_END = graph.insertEdge(parent, null, '', A_1_2_P2_END, A_1_And1_END ) /n var A_1_3_P21_END_A_1_And1_END = graph.insertEdge(parent, null, '', A_1_3_P21_END, A_1_And1_END ) /n var A_1_And1_END_A_2_And2 = graph.insertEdge(paren ...
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Test 4
p = Process("process")

p_con1 = p.Condition("Condition 1")
p1 = p_con1.Process("P1")
p2 = p_con1.Process("P2")
p3 = p_con1.Process("P3")
p_act1 = p1.Action("Action1")  

p_con2 = p1.Condition("Condition 2")
p21 = p_con2.Process("P21")
p22 = p_con2.Process("P22") 
p21.Action("Action22")  
p22.Action("Action23")

p_con3 = p2.Condition("Condition 3")
p31 = p_con3.Process("P31")
p32 = p_con3.Process("P32") 
p31.Action("Action32")  
p32.Action("Action33")


p_con4 = p3.Condition("Condition 4")
p41 = p_con4.Process("P41")
p42 = p_con4.Process("P42") 
p41.Action("Action42")  
p42.Action("Action43")

p.Action("Action4") 

IFrame("http://localhost:8080/?g=" + p.get_mxgraph(), width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="http://localhost:8080/?g=var A_process = graph.insertVertex(parent, 'A process', '', 505.0, 42.0, 30, 30, 'Process') /n A_process.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_And1 = graph.insertVertex(parent, 'A.1 And1', 'And1', 480.0, 84.0, 80, 30, 'Condition') /n A_1_And1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_process_A_1_And1 = graph.insertEdge(parent, null, '', A_process, A_1_And1, 'Arrow_Edge_Process' ) /n var A_1_1_P1 = graph.insertVertex(parent, 'A.1.1 P1', '', 200.0, 141.0, 0, 0, 'Process') /n A_1_1_P1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_And1_A_1_1_P1 = graph.insertEdge(parent, null, '', A_1_And1, A_1_1_P1 ) /n var A_1_2_P2 = graph.insertVertex(parent, 'A.1.2 P2', '', 520.0, 141.0, 0, 0, 'Process') /n A_1_2_P2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_And1_A_1_2_P2 = graph.insertEdge(parent, null, '', A_1_And1, A_1_2_P2 ) /n var A_1_3_P3 = graph.insertVertex(parent, 'A.1.3 P3', '', 840.0, 141.0, 0, 0, 'Process') /n A_1_3_P3.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_And1_A_1_3_P3 = graph.insertEdge(parent, null, '', A_1_And1, A_1_3_P3 ) /n var A_2_Action4 = graph.insertVertex(parent, 'A.2 Action4', 'Action4', 480.0, 504.0, 80, 30, 'Action') /n A_2_Action4.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_process_END = graph.insertVertex(parent, 'A process_END', '', 505.0, 546.0, 30, 30, 'Process_END') /n A_process_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_2_Action4_A_process_END = graph.insertEdge(parent, null, '', A_2_Action4, A_process_END, 'Arrow_Edge_Process' ) /n var A_1_1_1_Action1 = graph.insertVertex(parent, 'A.1.1.1 Action1', 'Action1', 160.0, 168.0, 80, 30, 'Action') /n A_1_1_1_Action1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_1_P1_A_1_1_1_Action1 = graph.insertEdge(parent, null, '', A_1_1_P1, A_1_1_1_Action1 ) /n var A_1_2_1_And3 = graph.insertVertex(parent, 'A.1.2.1 And3', 'And3', 480.0, 168.0, 80, 30, 'Condition') /n A_1_2_1_And3.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_2_P2_A_1_2_1_And3 = graph.insertEdge(parent, null, '', A_1_2_P2, A_1_2_1_And3 ) /n var A_1_3_1_And4 = graph.insertVertex(parent, 'A.1.3.1 And4', 'And4', 800.0, 168.0, 80, 30, 'Condition') /n A_1_3_1_And4.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_3_P3_A_1_3_1_And4 = graph.insertEdge(parent, null, '', A_1_3_P3, A_1_3_1_And4 ) /n var A_1_1_2_And2 = graph.insertVertex(parent, 'A.1.1.2 And2', 'And2', 160.0, 210.0, 80, 30, 'Condition') /n A_1_1_2_And2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_1_1_Action1_A_1_1_2_And2 = graph.insertEdge(parent, null, '', A_1_1_1_Action1, A_1_1_2_And2 ) /n var A_1_1_2_1_P21 = graph.insertVertex(parent, 'A.1.1.2.1 P21', '', 120.0, 267.0, 0, 0, 'Process') /n A_1_1_2_1_P21.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_1_2_And2_A_1_1_2_1_P21 = graph.insertEdge(parent, null, '', A_1_1_2_And2, A_1_1_2_1_P21 ) /n var A_1_1_2_2_P22 = graph.insertVertex(parent, 'A.1.1.2.2 P22', '', 280.0, 267.0, 0, 0, 'Process') /n A_1_1_2_2_P22.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_1_2_And2_A_1_1_2_2_P22 = graph.insertEdge(parent, null, '', A_1_1_2_And2, A_1_1_2_2_P22 ) /n var A_1_1_2_1_1_Action22 = graph.insertVertex(parent, 'A.1.1.2.1.1 Action22', 'Action22', 80.0, 294.0, 80, 30, 'Action') /n A_1_1_2_1_1_Action22.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_1_2_1_P21_A_1_1_2_1_1_Action22 = graph.insertEdge(parent, null, '', A_1_1_2_1_P21, A_1_1_2_1_1_Action22 ) /n var A_1_1_2_2_1_Action23 = graph.insertVertex(parent, 'A.1.1.2.2.1 Action23', 'Action23', 240.0, 294.0, 80, 30, 'Action') /n A_1_1_2_2_1_Action23.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_1_2_2_P22_A_1_1_2_2_1_Action23 = graph.insertEdge(parent, null, '', A_1_1_2_2_P22, A_1_1_2_2_1_Act ...

# %%
# Test 4
p = Process("process")

p_con1 = p.Condition("Condition 1")
p1 = p_con1.Process("P1")
p2 = p_con1.Process("P2")
p3 = p_con1.Process("P3")

p_act1 = p1.Action("동기화")  

p_con2 = p1.Condition("Condition 2")
p21 = p_con2.Process("P21")
p22 = p_con2.Process("P22") 

p21.Action("기능11")
p21.Action("기능12")
p21.Action("기능13")
p21.Action("기능14")
p21.Action("기능15")
p21.Action("기능16")

p22.Action("기능21")
p22.Action("기능22")
p22.Action("기능23")
p22.Action("기능24")
p22.Action("기능25")
p22.Action("기능26")


p_con3 = p2.Condition("Condition 3")
p31 = p_con3.Process("P31")
p32 = p_con3.Process("P32") 

p31.Action("Action32")  
p32.Action("Action33")


p_con4 = p3.Condition("Condition 4")
p41 = p_con4.Process("P41")
p42 = p_con4.Process("P42") 

p41.Action("Action42")  
p42.Action("Action43")

p.Action("Action4") 

IFrame("http://localhost:8080/?g=" + p.get_mxgraph(), width=1000, height=700)
# Out:
#         <iframe
#             width="1000"
#             height="700"
#             src="http://localhost:8080/?g=var process = graph.insertVertex(parent, 'process', '', 505.0, 42.0, 30, 30, 'Process') /n process.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var And1 = graph.insertVertex(parent, 'And1', 'And1', 480.0, 84.0, 80, 30, 'Condition') /n And1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var process_And1 = graph.insertEdge(parent, null, '', process, And1, 'Arrow_Edge_Process' ) /n var P1 = graph.insertVertex(parent, 'P1', '', 200.0, 141.0, 0, 0, 'Process') /n P1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var And1_P1 = graph.insertEdge(parent, null, '', And1, P1 ) /n var P2 = graph.insertVertex(parent, 'P2', '', 520.0, 141.0, 0, 0, 'Process') /n P2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var And1_P2 = graph.insertEdge(parent, null, '', And1, P2 ) /n var P3 = graph.insertVertex(parent, 'P3', '', 840.0, 141.0, 0, 0, 'Process') /n P3.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var And1_P3 = graph.insertEdge(parent, null, '', And1, P3 ) /n var Action4 = graph.insertVertex(parent, 'Action4', 'Action4', 480.0, 714.0, 80, 30, 'Action') /n Action4.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var process_END = graph.insertVertex(parent, 'process_END', '', 505.0, 756.0, 30, 30, 'Process_END') /n process_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var Action4_process_END = graph.insertEdge(parent, null, '', Action4, process_END, 'Arrow_Edge_Process' ) /n var 동기화 = graph.insertVertex(parent, '동기화', '동기화', 160.0, 168.0, 80, 30, 'Action') /n 동기화.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var P1_동기화 = graph.insertEdge(parent, null, '', P1, 동기화 ) /n var And3 = graph.insertVertex(parent, 'And3', 'And3', 480.0, 168.0, 80, 30, 'Condition') /n And3.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var P2_And3 = graph.insertEdge(parent, null, '', P2, And3 ) /n var And4 = graph.insertVertex(parent, 'And4', 'And4', 800.0, 168.0, 80, 30, 'Condition') /n And4.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var P3_And4 = graph.insertEdge(parent, null, '', P3, And4 ) /n var And2 = graph.insertVertex(parent, 'And2', 'And2', 160.0, 210.0, 80, 30, 'Condition') /n And2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var 동기화_And2 = graph.insertEdge(parent, null, '', 동기화, And2 ) /n var P21 = graph.insertVertex(parent, 'P21', '', 120.0, 267.0, 0, 0, 'Process') /n P21.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var And2_P21 = graph.insertEdge(parent, null, '', And2, P21 ) /n var P22 = graph.insertVertex(parent, 'P22', '', 280.0, 267.0, 0, 0, 'Process') /n P22.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var And2_P22 = graph.insertEdge(parent, null, '', And2, P22 ) /n var 기능11 = graph.insertVertex(parent, '기능11', '기능11', 80.0, 294.0, 80, 30, 'Action') /n 기능11.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var P21_기능11 = graph.insertEdge(parent, null, '', P21, 기능11 ) /n var 기능21 = graph.insertVertex(parent, '기능21', '기능21', 240.0, 294.0, 80, 30, 'Action') /n 기능21.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var P22_기능21 = graph.insertEdge(parent, null, '', P22, 기능21 ) /n var 기능12 = graph.insertVertex(parent, '기능12', '기능12', 80.0, 336.0, 80, 30, 'Action') /n 기능12.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var 기능11_기능12 = graph.insertEdge(parent, null, '', 기능11, 기능12 ) /n var 기능13 = graph.insertVertex(parent, '기능13', '기능13', 80.0, 378.0, 80, 30, 'Action') /n 기능13.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var 기능12_기능13 = graph.insertEdge(parent, null, '', 기능12, 기능13 ) /n var 기능14 = graph.insertVertex(parent, '기능14', '기능14', 80.0, 420.0, 80, 30, 'Action') /n 기능14.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var 기능13_기능14 = graph.insertEdge(parent, null, '', 기능13, 기능14 ) /n var 기능15 = graph.insertVertex(parent, '기능15', '기능15', 80.0, 462.0, 80, 30, 'Action') /n ...

# %%
    
p = Process("process")

p_con1 = p.Condition("Condition 1")
p1 = p_con1.Process("P1")
p2 = p_con1.Process("P2")
p3 = p_con1.Process("P3")
p_act1 = p1.Action("Action1")  
 
 
act42 = p1.Action("Action42")   

p1.Action("Action4") 

loop = p2.Loop(times=2)
pl1 = loop.Process("process1_1")

l_act3 = pl1.Action("Action111")

# i1 = Item('asdasd')

act42.sends(Item('나의 아이템111'), p_act1) 

IFrame("http://localhost:8080/?g=" + p.get_mxgraph(), width=1000, height=700)
# Out:
#         <iframe
#             width="1000"
#             height="700"
#             src="http://localhost:8080/?g=var process = graph.insertVertex(parent, 'process', '', 265.0, 42.0, 30, 30, 'Process') /n process.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var And1 = graph.insertVertex(parent, 'And1', 'And1', 240.0, 84.0, 80, 30, 'Condition') /n And1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var process_And1 = graph.insertEdge(parent, null, '', process, And1, 'Arrow_Edge_Process' ) /n var P1 = graph.insertVertex(parent, 'P1', '', 120.0, 141.0, 0, 0, 'Process') /n P1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var And1_P1 = graph.insertEdge(parent, null, '', And1, P1 ) /n var P2 = graph.insertVertex(parent, 'P2', '', 280.0, 141.0, 0, 0, 'Process') /n P2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var And1_P2 = graph.insertEdge(parent, null, '', And1, P2 ) /n var P3 = graph.insertVertex(parent, 'P3', '', 440.0, 141.0, 0, 0, 'Process') /n P3.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var And1_P3 = graph.insertEdge(parent, null, '', And1, P3 ) /n var Action1 = graph.insertVertex(parent, 'Action1', 'Action1', 80.0, 168.0, 80, 30, 'Action') /n Action1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var P1_Action1 = graph.insertEdge(parent, null, '', P1, Action1 ) /n var loop = graph.insertVertex(parent, 'loop', 'L', 265.0, 168.0, 30, 30, 'Loop') /n loop.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var P2_loop = graph.insertEdge(parent, null, '', P2, loop ) /n var P3_END = graph.insertVertex(parent, 'P3_END', '', 440.0, 393.0, 0, 0, 'Process_END') /n P3_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var P3_P3_END = graph.insertEdge(parent, null, '', P3, P3_END ) /n var Action42 = graph.insertVertex(parent, 'Action42', 'Action42', 80.0, 210.0, 80, 30, 'Action') /n Action42.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var Action1_Action42 = graph.insertEdge(parent, null, '', Action1, Action42 ) /n var Action4 = graph.insertVertex(parent, 'Action4', 'Action4', 80.0, 252.0, 80, 30, 'Action') /n Action4.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var Action42_Action4 = graph.insertEdge(parent, null, '', Action42, Action4 ) /n var P1_END = graph.insertVertex(parent, 'P1_END', '', 120.0, 393.0, 0, 0, 'Process_END') /n P1_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var Action4_P1_END = graph.insertEdge(parent, null, '', Action4, P1_END ) /n var And1_END = graph.insertVertex(parent, 'And1_END', 'OR', 265.0, 420.0, 30, 30, 'Condition_END') /n And1_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var P1_END_And1_END = graph.insertEdge(parent, null, '', P1_END, And1_END ) /n var process1_1 = graph.insertVertex(parent, 'process1_1', '', 280.0, 225.0, 0, 0, 'Process') /n process1_1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var loop_process1_1 = graph.insertEdge(parent, null, '', loop, process1_1 ) /n var Action111 = graph.insertVertex(parent, 'Action111', 'Action111', 240.0, 252.0, 80, 30, 'Action') /n Action111.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var process1_1_Action111 = graph.insertEdge(parent, null, '', process1_1, Action111 ) /n var process1_1_END = graph.insertVertex(parent, 'process1_1_END', '', 280.0, 309.0, 0, 0, 'Process_END') /n process1_1_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var Action111_process1_1_END = graph.insertEdge(parent, null, '', Action111, process1_1_END ) /n var loop_END = graph.insertVertex(parent, 'loop_END', 'L', 265.0, 336.0, 30, 30, 'Loop_END') /n loop_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var process1_1_END_loop_END = graph.insertEdge(parent, null, '', process1_1_END, loop_END ) /n var loop_END_loop = graph.insertEdge(parent, null, '', loop_END, loop, 'Arrow_Edge_Loop' ) /n loop_END_loop.geometry.points = [new mxPoint( 340.0, 0 )]/nvar P2_END = graph.insertVertex(parent, 'P2_END', '', 280.0, 393.0, 0, 0,  ...
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
p = Process("process")

p_con1 = p.Or()
p1 = p_con1.Process("P1")
p2 = p_con1.Process("P2")
p3 = p_con1.Process("P3")
act1 = p1.Action("Action1 Action1 Action1 Action1")
act2 = p3.Action("Action2")
act3 = p2.Action("Action3")
act4 = p2.Action("Action4")
act5 = p2.Action("Action5")
act6 = p2.Action("Action6")

i1 = Item("Item1")
i2 = Item("Item2")
i3 = Item("Item3")
i4 = Item("Item4")
i5 = Item("Item5")
i6 = Item("Item6")

act1.sends(i1, act2)
act1.sends(i3, act2)
act1.sends(i2, act2)
act1.sends(i4, act2)
act1.sends(i5, act2)
act1.sends(i6, act2)
 
IFrame("http://localhost:8080/?g=" + p.get_mxgraph(), width=800, height=700)
# Out:
#         <iframe
#             width="800"
#             height="700"
#             src="http://localhost:8080/?g=var process = graph.insertVertex(parent, 'process', '', 265.0, 42.0, 30, 30, 'Process') /n process.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var or = graph.insertVertex(parent, 'or', 'OR', 265.0, 84.0, 30, 30, 'Or') /n or.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var process_or = graph.insertEdge(parent, null, '', process, or, 'Arrow_Edge_Process' ) /n var P1 = graph.insertVertex(parent, 'P1', '', 120.0, 141.0, 0, 0, 'Process') /n P1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var or_P1 = graph.insertEdge(parent, null, '', or, P1 ) /n var P2 = graph.insertVertex(parent, 'P2', '', 280.0, 141.0, 0, 0, 'Process') /n P2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var or_P2 = graph.insertEdge(parent, null, '', or, P2 ) /n var P3 = graph.insertVertex(parent, 'P3', '', 440.0, 141.0, 0, 0, 'Process') /n P3.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var or_P3 = graph.insertEdge(parent, null, '', or, P3 ) /n var Action1_Action1_Action1_Action1 = graph.insertVertex(parent, 'Action1 Action1 Action1 Action1', 'Action1 Action1 Action1 Action1', 80.0, 168.0, 80, 30, 'Action') /n Action1_Action1_Action1_Action1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var P1_Action1_Action1_Action1_Action1 = graph.insertEdge(parent, null, '', P1, Action1_Action1_Action1_Action1 ) /n var Action3 = graph.insertVertex(parent, 'Action3', 'Action3', 240.0, 168.0, 80, 30, 'Action') /n Action3.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var P2_Action3 = graph.insertEdge(parent, null, '', P2, Action3 ) /n var Action2 = graph.insertVertex(parent, 'Action2', 'Action2', 400.0, 168.0, 80, 30, 'Action') /n Action2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var P3_Action2 = graph.insertEdge(parent, null, '', P3, Action2 ) /n var P1_END = graph.insertVertex(parent, 'P1_END', '', 120.0, 351.0, 0, 0, 'Process_END') /n P1_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var Action1_Action1_Action1_Action1_P1_END = graph.insertEdge(parent, null, '', Action1_Action1_Action1_Action1, P1_END ) /n var or_END = graph.insertVertex(parent, 'or_END', 'OR', 265.0, 378.0, 30, 30, 'Or_END') /n or_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var P1_END_or_END = graph.insertEdge(parent, null, '', P1_END, or_END ) /n var Action4 = graph.insertVertex(parent, 'Action4', 'Action4', 240.0, 210.0, 80, 30, 'Action') /n Action4.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var Action3_Action4 = graph.insertEdge(parent, null, '', Action3, Action4 ) /n var Action5 = graph.insertVertex(parent, 'Action5', 'Action5', 240.0, 252.0, 80, 30, 'Action') /n Action5.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var Action4_Action5 = graph.insertEdge(parent, null, '', Action4, Action5 ) /n var Action6 = graph.insertVertex(parent, 'Action6', 'Action6', 240.0, 294.0, 80, 30, 'Action') /n Action6.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var Action5_Action6 = graph.insertEdge(parent, null, '', Action5, Action6 ) /n var P2_END = graph.insertVertex(parent, 'P2_END', '', 280.0, 351.0, 0, 0, 'Process_END') /n P2_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var Action6_P2_END = graph.insertEdge(parent, null, '', Action6, P2_END ) /n var P2_END_or_END = graph.insertEdge(parent, null, '', P2_END, or_END ) /n var P3_END = graph.insertVertex(parent, 'P3_END', '', 440.0, 351.0, 0, 0, 'Process_END') /n P3_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var Action2_P3_END = graph.insertEdge(parent, null, '', Action2, P3_END ) /n var P3_END_or_END = graph.insertEdge(parent, null, '', P3_END, or_END ) /n var process_END = graph.insertVertex(parent, 'process_END', '', 265.0, 420.0, 30, 30, 'Process_END') /n process_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var or_END_process_END = graph.insertEdge(parent, null, '', or_ ...
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
p = Process("process1")
con = p.Condition('Condition')

p1 = con.Process("p1")
p2 = con.Process("p2")

act1 = p1.Action("Action1")
act2 = p2.Action("Action2")

r1 = Resource("Resource1", amount=5)

act1.produces(r1, amount=10)
act2.consumes(r1, amount=10)

act1.sends(Item('나의 아이템111'), act2) 

IFrame("http://localhost:8080/?g=" + p.get_mxgraph(), width=400, height=700)
# Out:
#         <iframe
#             width="400"
#             height="700"
#             src="http://localhost:8080/?g=var process1 = graph.insertVertex(parent, 'process1', '', 185.0, 42.0, 30, 30, 'Process') /n process1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var con = graph.insertVertex(parent, 'con', 'con', 160.0, 84.0, 80, 30, 'Condition') /n con.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var process1_con = graph.insertEdge(parent, null, '', process1, con, 'Arrow_Edge_Process' ) /n var p1 = graph.insertVertex(parent, 'p1', '', 120.0, 141.0, 0, 0, 'Process') /n p1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var con_p1 = graph.insertEdge(parent, null, '', con, p1 ) /n var p2 = graph.insertVertex(parent, 'p2', '', 280.0, 141.0, 0, 0, 'Process') /n p2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var con_p2 = graph.insertEdge(parent, null, '', con, p2 ) /n var Action1 = graph.insertVertex(parent, 'Action1', 'Action1', 80.0, 168.0, 80, 30, 'Action') /n Action1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var p1_Action1 = graph.insertEdge(parent, null, '', p1, Action1 ) /n var Action2 = graph.insertVertex(parent, 'Action2', 'Action2', 240.0, 168.0, 80, 30, 'Action') /n Action2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var p2_Action2 = graph.insertEdge(parent, null, '', p2, Action2 ) /n var p1_END = graph.insertVertex(parent, 'p1_END', '', 120.0, 225.0, 0, 0, 'Process_END') /n p1_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var Action1_p1_END = graph.insertEdge(parent, null, '', Action1, p1_END ) /n var con_END = graph.insertVertex(parent, 'con_END', 'OR', 185.0, 252.0, 30, 30, 'Condition_END') /n con_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var p1_END_con_END = graph.insertEdge(parent, null, '', p1_END, con_END ) /n var p2_END = graph.insertVertex(parent, 'p2_END', '', 280.0, 225.0, 0, 0, 'Process_END') /n p2_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var Action2_p2_END = graph.insertEdge(parent, null, '', Action2, p2_END ) /n var p2_END_con_END = graph.insertEdge(parent, null, '', p2_END, con_END ) /n var process1_END = graph.insertVertex(parent, 'process1_END', '', 185.0, 294.0, 30, 30, 'Process_END') /n process1_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var con_END_process1_END = graph.insertEdge(parent, null, '', con_END, process1_END, 'Arrow_Edge_Process' ) /n var 나의_아이템111 = graph.insertVertex(parent, '나의 아이템111', '나의 아이템111', 169.0, 173.0, 62, 20, 'Item') /n 나의_아이템111.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var Action1_나의_아이템111 = graph.insertEdge(parent, null, '', Action1, 나의_아이템111, 'Edge_Item' ) /n var 나의_아이템111_Action2 = graph.insertEdge(parent, null, '', 나의_아이템111, Action2, 'Arrow_Edge_Item' ) /n var Resource1 = graph.insertVertex(parent, 'Resource1', 'Resource1', 169.0, 152.0, 62, 20, 'Resource') /n Resource1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var Action1_Resource1 = graph.insertEdge(parent, null, '', Action1, Resource1, 'Edge_Resource' ) /n var Resource1_Action2 = graph.insertEdge(parent, null, '', Resource1, Action2, 'Arrow_Edge_Resource' ) /n "
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
p = Process("process")

p_and = p.And()

p1 = p_and.Process("process 1")
p2 = p_and.Process("process 2")
p_act1 = p1.Action("Action 1")
p_act2 = p1.Action("Action 2")

loop = p2.Loop()
p_loop = loop.Process('Process in loop')
l_and = p_loop.And()

l_p1 = l_and.Process("proc3")
l_p2 = l_and.Process("proc4")
p1_act3 = l_p1.Action("Act3")
p2_act4 = l_p2.Action("Act4")

show(p)
# Out:
#            <iframe
#                width="960"
#                height="750"
#                src="http://localhost:8080/?g=var A_process = graph.insertVertex(parent, 'A process', '', 225.0, 42.0, 30, 30, 'Process') /n A_process.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_and = graph.insertVertex(parent, 'A.1 and', 'A', 225.0, 84.0, 30, 30, 'And') /n A_1_and.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_process_A_1_and = graph.insertEdge(parent, null, '', A_process, A_1_and, 'Arrow_Edge_Process' ) /n var A_1_1_process_1 = graph.insertVertex(parent, 'A.1.1 process 1', '', 120.0, 141.0, 0, 0, 'Process') /n A_1_1_process_1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_and_A_1_1_process_1 = graph.insertEdge(parent, null, '', A_1_and, A_1_1_process_1 ) /n var A_1_2_process_2 = graph.insertVertex(parent, 'A.1.2 process 2', '', 360.0, 141.0, 0, 0, 'Process') /n A_1_2_process_2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_and_A_1_2_process_2 = graph.insertEdge(parent, null, '', A_1_and, A_1_2_process_2 ) /n var A_1_1_1_Action_1 = graph.insertVertex(parent, 'A.1.1.1 Action 1', 'Action 1', 80.0, 168.0, 80, 30, 'Action') /n A_1_1_1_Action_1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_1_process_1_A_1_1_1_Action_1 = graph.insertEdge(parent, null, '', A_1_1_process_1, A_1_1_1_Action_1 ) /n var A_1_2_1_loop = graph.insertVertex(parent, 'A.1.2.1 loop', 'L', 345.0, 168.0, 30, 30, 'Loop') /n A_1_2_1_loop.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_2_process_2_A_1_2_1_loop = graph.insertEdge(parent, null, '', A_1_2_process_2, A_1_2_1_loop ) /n var A_1_1_2_Action_2 = graph.insertVertex(parent, 'A.1.1.2 Action 2', 'Action 2', 80.0, 210.0, 80, 30, 'Action') /n A_1_1_2_Action_2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_1_1_Action_1_A_1_1_2_Action_2 = graph.insertEdge(parent, null, '', A_1_1_1_Action_1, A_1_1_2_Action_2 ) /n var A_1_1_process_1_END = graph.insertVertex(parent, 'A.1.1 process 1_END', '', 120.0, 561.0, 0, 0, 'Process_END') /n A_1_1_process_1_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_1_2_Action_2_A_1_1_process_1_END = graph.insertEdge(parent, null, '', A_1_1_2_Action_2, A_1_1_process_1_END ) /n var A_1_and_END = graph.insertVertex(parent, 'A.1 and_END', 'OR', 225.0, 588.0, 30, 30, 'And_END') /n A_1_and_END.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_1_process_1_END_A_1_and_END = graph.insertEdge(parent, null, '', A_1_1_process_1_END, A_1_and_END ) /n var A_1_2_1_1_Process_in_loop = graph.insertVertex(parent, 'A.1.2.1.1 Process in loop', '', 360.0, 225.0, 0, 0, 'Process') /n A_1_2_1_1_Process_in_loop.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_2_1_loop_A_1_2_1_1_Process_in_loop = graph.insertEdge(parent, null, '', A_1_2_1_loop, A_1_2_1_1_Process_in_loop ) /n var A_1_2_1_1_1_and = graph.insertVertex(parent, 'A.1.2.1.1.1 and', 'A', 345.0, 252.0, 30, 30, 'And') /n A_1_2_1_1_1_and.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_2_1_1_Process_in_loop_A_1_2_1_1_1_and = graph.insertEdge(parent, null, '', A_1_2_1_1_Process_in_loop, A_1_2_1_1_1_and ) /n var A_1_2_1_1_1_1_proc3 = graph.insertVertex(parent, 'A.1.2.1.1.1.1 proc3', '', 280.0, 309.0, 0, 0, 'Process') /n A_1_2_1_1_1_1_proc3.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_2_1_1_1_and_A_1_2_1_1_1_1_proc3 = graph.insertEdge(parent, null, '', A_1_2_1_1_1_and, A_1_2_1_1_1_1_proc3 ) /n var A_1_2_1_1_1_2_proc4 = graph.insertVertex(parent, 'A.1.2.1.1.1.2 proc4', '', 440.0, 309.0, 0, 0, 'Process') /n A_1_2_1_1_1_2_proc4.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var A_1_2_1_1_1_and_A_1_2_1_1_1_2_proc4 = graph.insertEdge(parent, null, '', A_1_2_1_1_1_and, A_1_2_1_1_1_2_proc4 ) /n var A_1_2_1_1_1_1_1_Act3 = graph.insertVertex(parent, 'A.1.2.1.1.1.1.1 Act3', 'Act3', 240.0, 336.0, 80, 30, 'Action') /n A_1_2_1_1_1_1_1_Act3.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n va ...
#                frameborder="0"
#                allowfullscreen
#            ></iframe>

# %%
p = Process("process")

p_con1 = p.Condition("Condition 1")

for i in range(10):
    p2 = p_con1.Process(f"P{i}")

    p_con2 = p2.Condition(f"Condition {i}_2")
    p21 = p_con2.Process(f"P{i}_1")
    p22 = p_con2.Process(f"P{i}_2")  
    
    for j in range(20):
        p21.Action(f"Action1_{i}_{j}") 
        p22.Action(f"Action2_{i}_{j}") 
    
show(p)
# Out:
#         <iframe
#             width="1000"
#             height="700"
#             src="http://localhost:8080/?g=var process = graph.insertVertex(parent, 'process', '', 1625.0, 42.0, 30, 30, 'Process') /n process.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var And1 = graph.insertVertex(parent, 'And1', 'And1', 1600.0, 84.0, 80, 30, 'Condition') /n And1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var process_And1 = graph.insertEdge(parent, null, '', process, And1, 'Arrow_Edge_Process' ) /n var P0 = graph.insertVertex(parent, 'P0', '', 200.0, 141.0, 0, 0, 'Process') /n P0.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var And1_P0 = graph.insertEdge(parent, null, '', And1, P0 ) /n var P1 = graph.insertVertex(parent, 'P1', '', 520.0, 141.0, 0, 0, 'Process') /n P1.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var And1_P1 = graph.insertEdge(parent, null, '', And1, P1 ) /n var P2 = graph.insertVertex(parent, 'P2', '', 840.0, 141.0, 0, 0, 'Process') /n P2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var And1_P2 = graph.insertEdge(parent, null, '', And1, P2 ) /n var P3 = graph.insertVertex(parent, 'P3', '', 1160.0, 141.0, 0, 0, 'Process') /n P3.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var And1_P3 = graph.insertEdge(parent, null, '', And1, P3 ) /n var P4 = graph.insertVertex(parent, 'P4', '', 1480.0, 141.0, 0, 0, 'Process') /n P4.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var And1_P4 = graph.insertEdge(parent, null, '', And1, P4 ) /n var P5 = graph.insertVertex(parent, 'P5', '', 1800.0, 141.0, 0, 0, 'Process') /n P5.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var And1_P5 = graph.insertEdge(parent, null, '', And1, P5 ) /n var P6 = graph.insertVertex(parent, 'P6', '', 2120.0, 141.0, 0, 0, 'Process') /n P6.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var And1_P6 = graph.insertEdge(parent, null, '', And1, P6 ) /n var P7 = graph.insertVertex(parent, 'P7', '', 2440.0, 141.0, 0, 0, 'Process') /n P7.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var And1_P7 = graph.insertEdge(parent, null, '', And1, P7 ) /n var P8 = graph.insertVertex(parent, 'P8', '', 2760.0, 141.0, 0, 0, 'Process') /n P8.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var And1_P8 = graph.insertEdge(parent, null, '', And1, P8 ) /n var P9 = graph.insertVertex(parent, 'P9', '', 3080.0, 141.0, 0, 0, 'Process') /n P9.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var And1_P9 = graph.insertEdge(parent, null, '', And1, P9 ) /n var And0_2 = graph.insertVertex(parent, 'And0_2', 'And0_2', 160.0, 168.0, 80, 30, 'Condition') /n And0_2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var P0_And0_2 = graph.insertEdge(parent, null, '', P0, And0_2 ) /n var And1_2 = graph.insertVertex(parent, 'And1_2', 'And1_2', 480.0, 168.0, 80, 30, 'Condition') /n And1_2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var P1_And1_2 = graph.insertEdge(parent, null, '', P1, And1_2 ) /n var And2_2 = graph.insertVertex(parent, 'And2_2', 'And2_2', 800.0, 168.0, 80, 30, 'Condition') /n And2_2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var P2_And2_2 = graph.insertEdge(parent, null, '', P2, And2_2 ) /n var And3_2 = graph.insertVertex(parent, 'And3_2', 'And3_2', 1120.0, 168.0, 80, 30, 'Condition') /n And3_2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var P3_And3_2 = graph.insertEdge(parent, null, '', P3, And3_2 ) /n var And4_2 = graph.insertVertex(parent, 'And4_2', 'And4_2', 1440.0, 168.0, 80, 30, 'Condition') /n And4_2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var P4_And4_2 = graph.insertEdge(parent, null, '', P4, And4_2 ) /n var And5_2 = graph.insertVertex(parent, 'And5_2', 'And5_2', 1760.0, 168.0, 80, 30, 'Condition') /n And5_2.geometry.alternateBounds = new mxRectangle(0, 0, 60, 30) /n var P5_And5_2 = graph.insertEdge(parent, null, '', P5, And5_2 ) /n var And6_2 = graph.insertVertex(parent, 'And6_2', 'And6_2', 2080.0, 168.0, 80, 30, ' ...
