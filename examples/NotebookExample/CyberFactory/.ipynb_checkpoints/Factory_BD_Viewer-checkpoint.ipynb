# %%
import os
import sys 
sys.path.insert(0, os.path.abspath('..\..\..\..\sysmpy'))  
from sysmpy import * 
from sysmpy.gui.mxgraph.tornado_gui_server import *

# %%
p = Process('Process')
PS, IF, HT, HR, SP, CR, AL, PL, FR, SL, IL = p.And('Production Start', 'Induction Furnace', 'Heater', 'Hot Rolling Mill', 'Scalper', 
                    'Cold Rolling Mill', 'Annealing Line', 'Pickling Line', 'Finish Rolling Mill','Slitting Line', 'Inspection Line')

IF.Property('Speed', range=Normal(300, 10))
IF.Property('Temperature', range=Normal(1000, 10))

HT.Property('Speed', range=Normal(300, 10))
HT.Property('Temperature', range=Normal(1200, 10))

HR.Property('RG', range=Normal(10, 0.1))
HR.Property('RF', range=Normal(400, 10))

SP.Property('Gap', range=Normal(900, 10))

CR.Property('RG', range=Normal(5, 0.1))
CR.Property('RF', range=Normal(200, 10))

AL.Property('Speed', range=Normal(300, 10))
AL.Property('Temperature', range=Normal(90, 10))

PL.Property('Speed', range=Normal(300, 10))

FR.Property('RG', range=Normal(2, 0.1))
FR.Property('RF', range=Normal(50, 3))

SL.Property('Speed', range=Normal(300, 10)) 

IL.Property('Speed', range=Normal(300, 10)) 


PS_a = PS.Action('Supplying')
IF_a = IF.Action('Casting and Cutting')
HT_a = HT.Action('Heating')
HR_a = HR.Action('Hot Rolling')
SP_a = SP.Action('Scalping')
CR_a = CR.Action('Cold Rolling')
AL_a = AL.Action('Annealing')
PL_a = PL.Action('Pickling')
FR_a = FR.Action('Finish Rolling')
SL_a = SL.Action('Slitting')
IL_a = IL.Action('Inspection')

CTH = Item('Copper Cathode')
CTH.Property('Thickness', range=Normal(900, 10))
CTH.Property('Width', range=Normal(1100, 10))
CTH.Property('Length', range=Normal(1000, 10))
CTH.Property('Temperature', range=Normal(25, 5))
SLB = Item('Slab')
SLB.Property('Thickness', range=Normal(250, 10))
SLB.Property('Width', range=Normal(650, 10))
SLB.Property('Length', range=Normal(6000, 10))
SLB.Property('Temperature', range=Normal(600, 30))
HSL = Item('Heated Slab')
HSL.Property('Thickness', range=Normal(250, 10))
HSL.Property('Width', range=Normal(650, 10))
HSL.Property('Length', range=Normal(6000, 10))
HSL.Property('Temperature', range=Normal(1200, 30))
HSC = Item('Hot Strip Coil')
HSC.Property('Thickness', range=Normal(10, 5))
HSC.Property('Width', range=Normal(600, 5))
HSC.Property('Length', range=Normal(150000, 5))
HSC.Property('Temperature', range=Normal(900, 5))
SSC = Item('Scalped Strip Coil')
SSC.Property('Thickness', range=Normal(9, 1))
SSC.Property('Width', range=Normal(600, 1))
SSC.Property('Length', range=Normal(166666, 1))
SSC.Property('Temperature', range=Normal(50, 10))
CSC = Item('Cold Strip Coil')
CSC.Property('Thickness', range=Normal(5, 1))
CSC.Property('Width', range=Normal(600, 1))
CSC.Property('Length', range=Normal(166770, 1))
CSC.Property('Temperature', range=Normal(30, 10))
ASC = Item('Annealed Strip Coil')
ASC.Property('Thickness', range=Normal(5, 0.1))
ASC.Property('Width', range=Normal(600, 0.1))
ASC.Property('Length', range=Normal(166770, 0.1))
ASC.Property('Temperature', range=Normal(100, 10))
LSC = Item('Cleaned Strip Coil')
LSC.Property('Thickness', range=Normal(5, 0.1))
LSC.Property('Width', range=Normal(600, 0.1))
LSC.Property('Length', range=Normal(166770, 0.1))
LSC.Property('Temperature', range=Normal(100, 5))
FSC = Item('Finished Strip Coil')
FSC.Property('Thickness', range=Normal(2, 0.1))
FSC.Property('Width', range=Normal(600, 0.1))
FSC.Property('Length', range=Normal(168880, 0.1))
FSC.Property('Temperature', range=Normal(25, 1))
TSC = Item('Slitting Strip Coil')
TSC.Property('Thickness', range=Normal(2, 0.1))
TSC.Property('Width', range=Normal(200, 0.1))
TSC.Property('Length', range=Normal(168880, 0.1))
TSC.Property('Temperature', range=Normal(25, 1))
NSC = Item('Final Strip Coil')
NSC.Property('Quality', range=Normal(90, 1)) 

PS_a.sends(CTH)
IF_a.sends(SLB)
HT_a.sends(HSL)
HR_a.sends(HSC)
SP_a.sends(SSC)
CR_a.sends(CSC)
AL_a.sends(ASC)
PL_a.sends(LSC)
FR_a.sends(FSC)
SL_a.sends(TSC)
IL_a.sends(NSC)

IF_a.triggered(CTH) 
HT_a.triggered(SLB)
HR_a.triggered(HSL)
SP_a.triggered(HSC)
CR_a.triggered(SSC)
AL_a.triggered(CSC)
PL_a.triggered(ASC)
FR_a.triggered(LSC)
SL_a.triggered(FSC)
IL_a.triggered(TSC)

# %%
show(p, diagram='bd', width=1500, height=700, Hide_No_Action_Process=True)
# Out:
#            <iframe
#                width="1500"
#                height="700"
#                src="http://127.0.0.1:9191/bd/?g=var ID2723759117448 = graph.insertVertex(parent, 'and.Production Start', 'Production Start', 20.0, 20.0, 150, 100, 'Process') /n graph.insertVertex(ID2723759117448, null, '', 0, 0, 150, 70, 'ProcessImage/8/image=http://127.0.0.1:9191/src/default_images/Production Start.png') /n graph.insertVertex(ID2723759117448, null, 'Supplying', 0, 0, 150, 20, 'ActionBoundary') /n var ID2723759118024 = graph.insertVertex(parent, 'Copper Cathode', 'Copper Cathode', 200.0, 20.0, 150, 100, 'Item') /n graph.insertVertex(ID2723759118024, null, '', 0, 0, 150, 70, 'ItemImage/8/image=http://127.0.0.1:9191/src/default_images/Copper Cathode.png') /n var ID2723716453576_p = graph.insertVertex(ID2723759118024, null, '', 0, 0, 150, 20, 'Property') /n var ID2723716453576_k = graph.insertVertex(ID2723716453576_p, null, 'Thick.', 0, 0, 75.0, 20, 'Property') /n var ID2723716453576_v = graph.insertVertex(ID2723716453576_p, 'Copper Cathode.Thickness', 'null', 75.0, 0, 75.0, 20, 'Property') /n var ID2723759118856_p = graph.insertVertex(ID2723759118024, null, '', 0, 0, 150, 20, 'Property') /n var ID2723759118856_k = graph.insertVertex(ID2723759118856_p, null, 'Width.', 0, 0, 75.0, 20, 'Property') /n var ID2723759118856_v = graph.insertVertex(ID2723759118856_p, 'Copper Cathode.Width', 'null', 75.0, 0, 75.0, 20, 'Property') /n var ID2723759119880_p = graph.insertVertex(ID2723759118024, null, '', 0, 0, 150, 20, 'Property') /n var ID2723759119880_k = graph.insertVertex(ID2723759119880_p, null, 'Lengt.', 0, 0, 75.0, 20, 'Property') /n var ID2723759119880_v = graph.insertVertex(ID2723759119880_p, 'Copper Cathode.Length', 'null', 75.0, 0, 75.0, 20, 'Property') /n var ID2723759119624_p = graph.insertVertex(ID2723759118024, null, '', 0, 0, 150, 20, 'Property') /n var ID2723759119624_k = graph.insertVertex(ID2723759119624_p, null, 'Tempe.', 0, 0, 75.0, 20, 'Property') /n var ID2723759119624_v = graph.insertVertex(ID2723759119624_p, 'Copper Cathode.Temperature', 'null', 75.0, 0, 75.0, 20, 'Property') /n var ID2723759120264 = graph.insertVertex(parent, 'and.Induction Furnace', 'Induction Furnace', 380.0, 20.0, 150, 100, 'Process') /n graph.insertVertex(ID2723759120264, null, '', 0, 0, 150, 70, 'ProcessImage/8/image=http://127.0.0.1:9191/src/default_images/Induction Furnace.png') /n graph.insertVertex(ID2723759120264, null, 'Casting and Cutting', 0, 0, 150, 20, 'ActionBoundary') /n var ID2723759099976_p = graph.insertVertex(ID2723759120264, null, '', 0, 0, 150, 20, 'Property') /n var ID2723759099976_k = graph.insertVertex(ID2723759099976_p, null, 'Speed.', 0, 0, 75.0, 20, 'Property') /n var ID2723759099976_v = graph.insertVertex(ID2723759099976_p, 'Induction Furnace.Speed', 'null', 75.0, 0, 75.0, 20, 'Property') /n var ID2723759100680_p = graph.insertVertex(ID2723759120264, null, '', 0, 0, 150, 20, 'Property') /n var ID2723759100680_k = graph.insertVertex(ID2723759100680_p, null, 'Tempe.', 0, 0, 75.0, 20, 'Property') /n var ID2723759100680_v = graph.insertVertex(ID2723759100680_p, 'Induction Furnace.Temperature', 'null', 75.0, 0, 75.0, 20, 'Property') /n var ID2723759101576 = graph.insertVertex(parent, 'Slab', 'Slab', 560.0, 20.0, 150, 100, 'Item') /n graph.insertVertex(ID2723759101576, null, '', 0, 0, 150, 70, 'ItemImage/8/image=http://127.0.0.1:9191/src/default_images/Slab.png') /n var ID2723759121608_p = graph.insertVertex(ID2723759101576, null, '', 0, 0, 150, 20, 'Property') /n var ID2723759121608_k = graph.insertVertex(ID2723759121608_p, null, 'Thick.', 0, 0, 75.0, 20, 'Property') /n var ID2723759121608_v = graph.insertVertex(ID2723759121608_p, 'Slab.Thickness', 'null', 75.0, 0, 75.0, 20, 'Property') /n var ID2723759142024_p = graph.insertVertex(ID2723759101576, null, '', 0, 0, 150, 20, 'Property') /n var ID2723759142024_k = graph.insertVertex(ID2723759142024_p, null, 'Width.', 0, 0, 75.0, 20, 'Property') /n var ID2723759142024_v = graph.insertVertex(ID2723759142024_p, 'Slab.Width', 'null', 75.0, 0, 75.0, 20, 'Property')  ...
