# %%
import os
import sys 
sys.path.insert(0, os.path.abspath('..\..\..\..\sysmpy'))  
from sysmpy import * 
from sysmpy.gui.mxgraph.tornado_gui_server import *

# %%
RunServer()
# Out:
# E:\SW-SysMPy\SysMPy\examples\NotebookExample\CyberFactory/images
# We use the existing tornado server!

# %%
p = Process('Process')
PS, IF, HT, HR, SP, CR, AL, PL, FR, SL, IL = p.And('Production Start', 'Induction Furnace', 'Heater', 'Hot Rolling Mill', 'Scalper', 
                    'Cold Rolling Mill', 'Annealing Line', 'Pickling Line', 'Finish Rolling Mill','Slitting Line', 'Inspection Line')

IF.Property('Speed', range=Normal(300, 10))
IF.Property('Temperature', range=Normal(1000, 10))
HT.Property('Speed', range=Normal(300, 10))
HT.Property('Temperature', range=Normal(1200, 10))
HR.Property('RG', range=Normal(10, 0.1))
HR.Property('RF', range=Normal(400, 10))
SP.Property('Gap', range=Normal(900, 10))
CR.Property('RG', range=Normal(5, 0.1))
CR.Property('RF', range=Normal(200, 10))
AL.Property('Speed', range=Normal(300, 10))
AL.Property('Temperature', range=Normal(90, 10))
PL.Property('Speed', range=Normal(300, 10))
FR.Property('RG', range=Normal(2, 0.1))
FR.Property('RF', range=Normal(50, 3))
SL.Property('Speed', range=Normal(300, 10)) 
IL.Property('Speed', range=Normal(300, 10)) 


PS_a = PS.Action('Supplying')
IF_a = IF.Action('Casting and Cutting')
HT_a = HT.Action('Heating')
HR_a = HR.Action('Hot Rolling')
SP_a = SP.Action('Scalping')
CR_a = CR.Action('Cold Rolling')
AL_a = AL.Action('Annealing')
PL_a = PL.Action('Pickling')
FR_a = FR.Action('Finish Rolling')
SL_a = SL.Action('Slitting')
IL_a = IL.Action('Inspection')

CTH = Item('Copper Cathode')
CTH.Property('Thickness', range=Normal(900, 10))
CTH.Property('Width', range=Normal(1100, 10))
CTH.Property('Length', range=Normal(1000, 10))
CTH.Property('Temperature', range=Normal(25, 5))
SLB = Item('Slab')
SLB.Property('Thickness', range=Normal(250, 10))
SLB.Property('Width', range=Normal(650, 10))
SLB.Property('Length', range=Normal(6000, 10))
SLB.Property('Temperature', range=Normal(600, 30))
HSL = Item('Heated Slab')
HSL.Property('Thickness', range=Normal(250, 10))
HSL.Property('Width', range=Normal(650, 10))
HSL.Property('Length', range=Normal(6000, 10))
HSL.Property('Temperature', range=Normal(1200, 30))
HSC = Item('Hot Strip Coil')
HSC.Property('Thickness', range=Normal(10, 5))
HSC.Property('Width', range=Normal(600, 5))
HSC.Property('Length', range=Normal(150000, 5))
HSC.Property('Temperature', range=Normal(900, 5))
SSC = Item('Scalped Strip Coil')
SSC.Property('Thickness', range=Normal(9, 1))
SSC.Property('Width', range=Normal(600, 1))
SSC.Property('Length', range=Normal(166666, 1))
SSC.Property('Temperature', range=Normal(50, 10))
CSC = Item('Cold Strip Coil')
CSC.Property('Thickness', range=Normal(5, 1))
CSC.Property('Width', range=Normal(600, 1))
CSC.Property('Length', range=Normal(166770, 1))
CSC.Property('Temperature', range=Normal(30, 10))
ASC = Item('Annealed Strip Coil')
ASC.Property('Thickness', range=Normal(5, 0.1))
ASC.Property('Width', range=Normal(600, 0.1))
ASC.Property('Length', range=Normal(166770, 0.1))
ASC.Property('Temperature', range=Normal(100, 10))
LSC = Item('Cleaned Strip Coil')
LSC.Property('Thickness', range=Normal(5, 0.1))
LSC.Property('Width', range=Normal(600, 0.1))
LSC.Property('Length', range=Normal(166770, 0.1))
LSC.Property('Temperature', range=Normal(100, 5))
FSC = Item('Finished Strip Coil')
FSC.Property('Thickness', range=Normal(2, 0.1))
FSC.Property('Width', range=Normal(600, 0.1))
FSC.Property('Length', range=Normal(168880, 0.1))
FSC.Property('Temperature', range=Normal(25, 1))
TSC = Item('Slitting Strip Coil')
TSC.Property('Thickness', range=Normal(2, 0.1))
TSC.Property('Width', range=Normal(200, 0.1))
TSC.Property('Length', range=Normal(168880, 0.1))
TSC.Property('Temperature', range=Normal(25, 1))
NSC = Item('Final Strip Coil')
NSC.Property('Quality', range=Normal(90, 1)) 

PS_a.sends(CTH)
IF_a.sends(SLB)
HT_a.sends(HSL)
HR_a.sends(HSC)
SP_a.sends(SSC)
CR_a.sends(CSC)
AL_a.sends(ASC)
PL_a.sends(LSC)
FR_a.sends(FSC)
SL_a.sends(TSC)
IL_a.sends(NSC)

IF_a.triggered(CTH) 
HT_a.triggered(SLB)
HR_a.triggered(HSL)
SP_a.triggered(HSC)
CR_a.triggered(SSC)
AL_a.triggered(CSC)
PL_a.triggered(ASC)
FR_a.triggered(LSC)
SL_a.triggered(FSC)
IL_a.triggered(TSC)

# %%
show(p, diagram='ad', width=1400, height=300)
# Out:
#            <iframe
#                width="1400"
#                height="300"
#                src="http://127.0.0.1:9191/ad/?g=var A_Process = graph.insertVertex(parent, 'A Process', '', 905.0, 42.0, 30, 30, 'Process') /n var A_1_and = graph.insertVertex(parent, 'A.1 and', 'A', 905.0, 84.0, 30, 30, 'And') /n var A_Process_A_1_and = graph.insertEdge(parent, null, '', A_Process, A_1_and, 'Arrow_Edge_Process' ) /n var A_1_1_Production_Start = graph.insertVertex(parent, 'A.1.1 Production Start', '', 120.0, 141.0, 0, 0, 'Process') /n var A_1_and_A_1_1_Production_Start = graph.insertEdge(parent, null, '', A_1_and, A_1_1_Production_Start ) /n var A_1_2_Induction_Furnace = graph.insertVertex(parent, 'A.1.2 Induction Furnace', '', 280.0, 141.0, 0, 0, 'Process') /n var A_1_and_A_1_2_Induction_Furnace = graph.insertEdge(parent, null, '', A_1_and, A_1_2_Induction_Furnace ) /n var A_1_3_Heater = graph.insertVertex(parent, 'A.1.3 Heater', '', 440.0, 141.0, 0, 0, 'Process') /n var A_1_and_A_1_3_Heater = graph.insertEdge(parent, null, '', A_1_and, A_1_3_Heater ) /n var A_1_4_Hot_Rolling_Mill = graph.insertVertex(parent, 'A.1.4 Hot Rolling Mill', '', 600.0, 141.0, 0, 0, 'Process') /n var A_1_and_A_1_4_Hot_Rolling_Mill = graph.insertEdge(parent, null, '', A_1_and, A_1_4_Hot_Rolling_Mill ) /n var A_1_5_Scalper = graph.insertVertex(parent, 'A.1.5 Scalper', '', 760.0, 141.0, 0, 0, 'Process') /n var A_1_and_A_1_5_Scalper = graph.insertEdge(parent, null, '', A_1_and, A_1_5_Scalper ) /n var A_1_6_Cold_Rolling_Mill = graph.insertVertex(parent, 'A.1.6 Cold Rolling Mill', '', 920.0, 141.0, 0, 0, 'Process') /n var A_1_and_A_1_6_Cold_Rolling_Mill = graph.insertEdge(parent, null, '', A_1_and, A_1_6_Cold_Rolling_Mill ) /n var A_1_7_Annealing_Line = graph.insertVertex(parent, 'A.1.7 Annealing Line', '', 1080.0, 141.0, 0, 0, 'Process') /n var A_1_and_A_1_7_Annealing_Line = graph.insertEdge(parent, null, '', A_1_and, A_1_7_Annealing_Line ) /n var A_1_8_Pickling_Line = graph.insertVertex(parent, 'A.1.8 Pickling Line', '', 1240.0, 141.0, 0, 0, 'Process') /n var A_1_and_A_1_8_Pickling_Line = graph.insertEdge(parent, null, '', A_1_and, A_1_8_Pickling_Line ) /n var A_1_9_Finish_Rolling_Mill = graph.insertVertex(parent, 'A.1.9 Finish Rolling Mill', '', 1400.0, 141.0, 0, 0, 'Process') /n var A_1_and_A_1_9_Finish_Rolling_Mill = graph.insertEdge(parent, null, '', A_1_and, A_1_9_Finish_Rolling_Mill ) /n var A_1_10_Slitting_Line = graph.insertVertex(parent, 'A.1.10 Slitting Line', '', 1560.0, 141.0, 0, 0, 'Process') /n var A_1_and_A_1_10_Slitting_Line = graph.insertEdge(parent, null, '', A_1_and, A_1_10_Slitting_Line ) /n var A_1_11_Inspection_Line = graph.insertVertex(parent, 'A.1.11 Inspection Line', '', 1720.0, 141.0, 0, 0, 'Process') /n var A_1_and_A_1_11_Inspection_Line = graph.insertEdge(parent, null, '', A_1_and, A_1_11_Inspection_Line ) /n var A_1_1_1_Supplying = graph.insertVertex(parent, 'A.1.1.1 Supplying', 'Supplying', 80.0, 168.0, 80, 30, 'Action') /n var A_1_1_Production_Start_A_1_1_1_Supplying = graph.insertEdge(parent, null, '', A_1_1_Production_Start, A_1_1_1_Supplying ) /n var A_1_2_3_Casting_and_Cutting = graph.insertVertex(parent, 'A.1.2.3 Casting and Cutting', 'Casting and Cutting', 240.0, 168.0, 80, 30, 'Action') /n var A_1_2_Induction_Furnace_A_1_2_3_Casting_and_Cutting = graph.insertEdge(parent, null, '', A_1_2_Induction_Furnace, A_1_2_3_Casting_and_Cutting ) /n var A_1_3_3_Heating = graph.insertVertex(parent, 'A.1.3.3 Heating', 'Heating', 400.0, 168.0, 80, 30, 'Action') /n var A_1_3_Heater_A_1_3_3_Heating = graph.insertEdge(parent, null, '', A_1_3_Heater, A_1_3_3_Heating ) /n var A_1_4_3_Hot_Rolling = graph.insertVertex(parent, 'A.1.4.3 Hot Rolling', 'Hot Rolling', 560.0, 168.0, 80, 30, 'Action') /n var A_1_4_Hot_Rolling_Mill_A_1_4_3_Hot_Rolling = graph.insertEdge(parent, null, '', A_1_4_Hot_Rolling_Mill, A_1_4_3_Hot_Rolling ) /n var A_1_5_2_Scalping = graph.insertVertex(parent, 'A.1.5.2 Scalping', 'Scalping', 720.0, 168.0, 80, 30, 'Action') /n var A_1_5_Scalper_A_1_5_2_Scalping = graph.insertEdge(parent, null, '', A_1_5_Sc ...

# %%
show(p, diagram='bd', width=1500, height=700, Hide_No_Action_Process=True)
# Out:
#            <iframe
#                width="1500"
#                height="700"
#                src="http://127.0.0.1:9191/bd/?g=var ID1467634065032 = graph.insertVertex(parent, 'and.Production Start', 'Production Start', 20.0, 20.0, 150, 100, 'Process') /n graph.insertVertex(ID1467634065032, null, '', 0, 0, 150, 70, 'ProcessImage/8/image=http://127.0.0.1:9191/images/Production Start.png') /n graph.insertVertex(ID1467634065032, null, 'Supplying', 0, 0, 150, 20, 'ActionBoundary') /n var ID1467634063048 = graph.insertVertex(parent, 'Copper Cathode', 'Copper Cathode', 200.0, 20.0, 150, 100, 'Item') /n graph.insertVertex(ID1467634063048, null, '', 0, 0, 150, 70, 'ItemImage/8/image=http://127.0.0.1:9191/images/Copper Cathode.png') /n var ID1467634063368_p = graph.insertVertex(ID1467634063048, null, '', 0, 0, 150, 20, 'Property') /n var ID1467634063368_k = graph.insertVertex(ID1467634063368_p, null, 'Thick.', 0, 0, 75.0, 20, 'Property') /n var ID1467634063368_v = graph.insertVertex(ID1467634063368_p, 'Copper Cathode.Thickness', 'null', 75.0, 0, 75.0, 20, 'Property') /n var ID1467634063752_p = graph.insertVertex(ID1467634063048, null, '', 0, 0, 150, 20, 'Property') /n var ID1467634063752_k = graph.insertVertex(ID1467634063752_p, null, 'Width.', 0, 0, 75.0, 20, 'Property') /n var ID1467634063752_v = graph.insertVertex(ID1467634063752_p, 'Copper Cathode.Width', 'null', 75.0, 0, 75.0, 20, 'Property') /n var ID1467634064200_p = graph.insertVertex(ID1467634063048, null, '', 0, 0, 150, 20, 'Property') /n var ID1467634064200_k = graph.insertVertex(ID1467634064200_p, null, 'Lengt.', 0, 0, 75.0, 20, 'Property') /n var ID1467634064200_v = graph.insertVertex(ID1467634064200_p, 'Copper Cathode.Length', 'null', 75.0, 0, 75.0, 20, 'Property') /n var ID1467634064584_p = graph.insertVertex(ID1467634063048, null, '', 0, 0, 150, 20, 'Property') /n var ID1467634064584_k = graph.insertVertex(ID1467634064584_p, null, 'Tempe.', 0, 0, 75.0, 20, 'Property') /n var ID1467634064584_v = graph.insertVertex(ID1467634064584_p, 'Copper Cathode.Temperature', 'null', 75.0, 0, 75.0, 20, 'Property') /n var ID1467634061576 = graph.insertVertex(parent, 'and.Induction Furnace', 'Induction Furnace', 380.0, 20.0, 150, 100, 'Process') /n graph.insertVertex(ID1467634061576, null, '', 0, 0, 150, 70, 'ProcessImage/8/image=http://127.0.0.1:9191/images/Induction Furnace.png') /n graph.insertVertex(ID1467634061576, null, 'Casting and Cutting', 0, 0, 150, 20, 'ActionBoundary') /n var ID1467634062216_p = graph.insertVertex(ID1467634061576, null, '', 0, 0, 150, 20, 'Property') /n var ID1467634062216_k = graph.insertVertex(ID1467634062216_p, null, 'Speed.', 0, 0, 75.0, 20, 'Property') /n var ID1467634062216_v = graph.insertVertex(ID1467634062216_p, 'Induction Furnace.Speed', 'null', 75.0, 0, 75.0, 20, 'Property') /n var ID1467633913224_p = graph.insertVertex(ID1467634061576, null, '', 0, 0, 150, 20, 'Property') /n var ID1467633913224_k = graph.insertVertex(ID1467633913224_p, null, 'Tempe.', 0, 0, 75.0, 20, 'Property') /n var ID1467633913224_v = graph.insertVertex(ID1467633913224_p, 'Induction Furnace.Temperature', 'null', 75.0, 0, 75.0, 20, 'Property') /n var ID1467633909832 = graph.insertVertex(parent, 'Slab', 'Slab', 560.0, 20.0, 150, 100, 'Item') /n graph.insertVertex(ID1467633909832, null, '', 0, 0, 150, 70, 'ItemImage/8/image=http://127.0.0.1:9191/images/Slab.png') /n var ID1467633910152_p = graph.insertVertex(ID1467633909832, null, '', 0, 0, 150, 20, 'Property') /n var ID1467633910152_k = graph.insertVertex(ID1467633910152_p, null, 'Thick.', 0, 0, 75.0, 20, 'Property') /n var ID1467633910152_v = graph.insertVertex(ID1467633910152_p, 'Slab.Thickness', 'null', 75.0, 0, 75.0, 20, 'Property') /n var ID1467633910600_p = graph.insertVertex(ID1467633909832, null, '', 0, 0, 150, 20, 'Property') /n var ID1467633910600_k = graph.insertVertex(ID1467633910600_p, null, 'Width.', 0, 0, 75.0, 20, 'Property') /n var ID1467633910600_v = graph.insertVertex(ID1467633910600_p, 'Slab.Width', 'null', 75.0, 0, 75.0, 20, 'Property') /n var ID1467633910984_p = graph.insertVertex(ID ...
